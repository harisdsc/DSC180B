# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
consDF = pd.read_parquet("/uss/hdsi-prismdata/q2-ucsd-consDF.pqt")
consDF = consDF.drop(columns = ["credit_score"])
consDF = consDF.dropna()
acctDF = pd.read_parquet("/uss/hdsi-prismdata/q2-ucsd-acctDF.pqt")
trxnDF = pd.read_parquet("/uss/hdsi-prismdata/q2-ucsd-trxnDF.pqt")
catmap = pd.read_csv("/uss/hdsi-prismdata/q2-ucsd-cat-map.csv")

# %%
trxnDF.head()
# Out:
#   prism_consumer_id prism_transaction_id  category  amount credit_or_debit  \
# 0              3023                    0         4    0.05          CREDIT
# 1              3023                    1        12  481.56          CREDIT
# 2              3023                    2         4    0.05          CREDIT
# 3              3023                    3         4    0.07          CREDIT
# 4              3023                    4         4    0.06          CREDIT
#
#   posted_date
# 0  2021-04-16
# 1  2021-04-30
# 2  2021-05-16
# 3  2021-06-16
# 4  2021-07-16

# %%
acctDF.head()
# Out:
#   prism_consumer_id prism_account_id account_type balance_date   balance
# 0              3023                0      SAVINGS   2021-08-31     90.57
# 1              3023                1     CHECKING   2021-08-31    225.95
# 2              4416                2      SAVINGS   2022-03-31  15157.17
# 3              4416                3     CHECKING   2022-03-31     66.42
# 4              4227                4     CHECKING   2021-07-31   7042.90

# %%
trxnDF["signed_amount"] = np.where(
    trxnDF["credit_or_debit"] == "CREDIT",
    trxnDF["amount"],
    -trxnDF["amount"]
)

# %%
# net transactions per consumer
txn_sum = (
    trxnDF
    .groupby("prism_consumer_id", as_index=False)["signed_amount"]
    .sum()
    .rename(columns={"signed_amount": "total_transactions"})
)

# %%
# initial balance for each consumer
initial_balance = (
    acctDF
    .groupby("prism_consumer_id", as_index=False)["balance"]
    .sum()
    .rename(columns={"balance": "initial_balance"})
)

# %%
# final balance for each consumer
final_balance = (
    initial_balance
    .merge(txn_sum, on="prism_consumer_id", how="left")
    .fillna({"total_transactions": 0})
)

final_balance["final_balance"] = (
    final_balance["initial_balance"] +
    final_balance["total_transactions"]
)

final_balance
# Out:
#       prism_consumer_id  initial_balance  total_transactions  final_balance
# 0                     0           320.37             -521.59        -201.22
# 1                     1          3302.42             1805.43        5107.85
# 2                    10           824.24            -1190.04        -365.80
# 3                   100          2655.47            -4505.77       -1850.30
# 4                  1000            95.25              438.08         533.33
# ...                 ...              ...                 ...            ...
# 13004              9995             0.00             -121.55        -121.55
# 13005              9996           252.67                9.14         261.81
# 13006              9997           611.28              503.19        1114.47
# 13007              9998          -862.99             -833.10       -1696.09
# 13008              9999            -9.02             -319.43        -328.45
#
# [13009 rows x 4 columns]

# %%
final_balance[["initial_balance", "final_balance"]].describe()
# Out:
#        initial_balance  final_balance
# count     1.300900e+04   1.300900e+04
# mean      8.079853e+03   1.003303e+04
# std       5.306647e+04   7.794515e+04
# min      -9.261490e+03  -4.203443e+05
# 25%       3.251800e+02   3.805000e+01
# 50%       1.355610e+03   1.445600e+03
# 75%       4.953660e+03   6.289820e+03
# max       3.598370e+06   5.952758e+06

# %%
# number of consumers with <0 initial balance 
(final_balance["initial_balance"] < 0).sum()
# Out:
# 369

# %%
# number of conumers with <0 final balance
(final_balance["final_balance"] < 0).sum()
# Out:
# 2921

# %%
# consumers that went from positive to negative balance
(
    (final_balance["initial_balance"] >= 0) &
    (final_balance["final_balance"] < 0)
).sum()
# Out:
# 2613

# %%
total_initial = final_balance["initial_balance"].sum()
total_final = final_balance["final_balance"].sum()

# Create a simple plot
plt.figure(figsize=(5,4))
plt.bar(["Initial Balance", "Final Balance"], [total_initial, total_final], color=["orange", "green"])
plt.ylabel("Total Balance")
plt.title("Overall Balance Change Across All Consumers")
plt.show()

# %%
final_balance["final_balance_log"] = np.log1p(final_balance["final_balance"])

plt.figure(figsize=(7,4))
plt.hist(final_balance["final_balance_log"], bins=50, color="skyblue", edgecolor="black")
plt.xlabel("Log of Final Balance")
plt.ylabel("Number of Consumers")
plt.title("Distribution of Final Balances (Log-Transformed)")
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
final_balance["initial_balance_log"] = np.log1p(final_balance["initial_balance"])

plt.figure(figsize=(7,4))
plt.hist(final_balance["initial_balance_log"], bins=50, color="skyblue", edgecolor="black")
plt.xlabel("Log of Initial Balance")
plt.ylabel("Number of Consumers")
plt.title("Distribution of Initial Balances (Log-Transformed)")
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
plt.figure()
plt.hist(
    final_balance["initial_balance_log"],
    bins=100,
    alpha=0.6,
    label="Initial Balance"
)
plt.hist(
    final_balance["final_balance_log"],
    bins=100,
    alpha=0.6,
    label="Final Balance"
)
plt.xlabel("Balance")
plt.ylabel("Count")
plt.title("Initial vs Final Balance Distribution")
plt.legend()
plt.show()

# %%
sampled = (
    consDF
    .groupby("DQ_TARGET", group_keys=False)
    .apply(lambda x: x.sample(n=5, random_state=40))
)

sampled
# Out:
# /tmp/ipykernel_412/2876161650.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(n=5, random_state=40))
#       prism_consumer_id evaluation_date  DQ_TARGET
# 7085               7085      2023-01-18        0.0
# 5754               5754      2023-04-20        0.0
# 2894               2894      2022-01-01        0.0
# 562                 562      2022-02-01        0.0
# 8707               8707      2023-08-26        0.0
# 8843               8843      2023-08-29        1.0
# 12221             12221      2022-08-04        1.0
# 13073             13073      2021-12-23        1.0
# 7990               7990      2023-11-21        1.0
# 3099               3099      2021-03-01        1.0

# %%
balance_merged = sampled.merge(
    final_balance,
    on="prism_consumer_id",
    how="left"
)

balance_merged
# Out:
#   prism_consumer_id evaluation_date  DQ_TARGET  initial_balance  \
# 0              7085      2023-01-18        0.0          1061.38
# 1              5754      2023-04-20        0.0          5731.78
# 2              2894      2022-01-01        0.0          9422.39
# 3               562      2022-02-01        0.0          4428.22
# 4              8707      2023-08-26        0.0           952.49
# 5              8843      2023-08-29        1.0          2112.46
# 6             12221      2022-08-04        1.0          1141.35
# 7             13073      2021-12-23        1.0          4169.25
# 8              7990      2023-11-21        1.0           588.25
# 9              3099      2021-03-01        1.0            27.71
#
#    total_transactions  final_balance  final_balance_log  intial_balance_log  \
# 0           -15367.86      -14306.48                NaN            6.968267
# 1            -1201.05        4530.73           8.418859            8.653956
# 2              -10.41        9411.98           9.149845            9.150950
# 3             1444.86        5873.08           8.678305            8.395979
# 4             -750.51         201.98           5.313107            6.860129
# 5             2115.87        4228.33           8.349799            7.656082
# 6            -2753.10       -1611.75                NaN            7.040843
# 7              779.31        4948.56           8.507054            8.335731
# 8              560.42        1148.67           7.047230            6.378851
# 9              542.96         570.67           6.348562            3.357245
#
#    initial_balance_log
# 0             6.968267
# 1             8.653956
# 2             9.150950
# 3             8.395979
# 4             6.860129
# 5             7.656082
# 6             7.040843
# 7             8.335731
# 8             6.378851
# 9             3.357245

# %%
plt.figure()

plotted = set()

for _, row in balance_merged.iterrows():
    if row["DQ_TARGET"] == 0:
        label = "DQ = 0" if "DQ = 0" not in plotted else None
        plt.plot(
            ["Initial", "Final"],
            [row["initial_balance"], row["final_balance"]],
            marker="o",
            color="tab:blue",
            alpha=0.7,
            label=label
        )
        plotted.add("DQ = 0")
    else:
        label = "DQ = 1" if "DQ = 1" not in plotted else None
        plt.plot(
            ["Initial", "Final"],
            [row["initial_balance"], row["final_balance"]],
            marker="o",
            color="tab:orange",
            alpha=0.7,
            label=label
        )
        plotted.add("DQ = 1")

plt.ylabel("Balance")
plt.title("Initial vs Final Balance per Consumer (Colored by DQ)")
plt.legend()
plt.show()

# %%
trxnDF
# Out:
#         prism_consumer_id prism_transaction_id  category   amount  \
# 136802                  0               136738        14    27.62
# 136767                  0               136703        11  1400.00
# 136803                  0               136739        39    25.10
# 136804                  0               136740        37   500.00
# 136805                  0               136741        14    25.00
# ...                   ...                  ...       ...      ...
# 1524647              9999              1522635        16    66.63
# 1524648              9999              1522636        14    16.91
# 1524649              9999              1522637        14     3.52
# 1524650              9999              1522638        16     7.99
# 1524651              9999              1522639        16    16.99
#
#         credit_or_debit posted_date  signed_amount
# 136802            DEBIT  2021-03-16         -27.62
# 136767           CREDIT  2021-03-17        1400.00
# 136803            DEBIT  2021-03-17         -25.10
# 136804            DEBIT  2021-03-17        -500.00
# 136805            DEBIT  2021-03-18         -25.00
# ...                 ...         ...            ...
# 1524647           DEBIT  2023-08-08         -66.63
# 1524648           DEBIT  2023-08-08         -16.91
# 1524649           DEBIT  2023-08-08          -3.52
# 1524650           DEBIT  2023-08-08          -7.99
# 1524651           DEBIT  2023-08-08         -16.99
#
# [6407321 rows x 7 columns]

# %%
acctDF["balance_date"] = pd.to_datetime(acctDF["balance_date"])
dq_check = (
    acctDF
    .groupby(["prism_consumer_id", "account_type"])["balance_date"]
    .nunique()
    .reset_index()
)

# %%
# 66 consumers with different balance dates
dq_check[dq_check["balance_date"] != 1]
# Out:
#       prism_consumer_id account_type  balance_date
# 827                1056     CHECKING             2
# 1110               1077     CHECKING             2
# 1132               1079     CHECKING             2
# 2031               1147     CHECKING             2
# 2084               1151     CHECKING             2
# ...                 ...          ...           ...
# 17093                74     CHECKING             2
# 19340               896     CHECKING             2
# 20157               952     CHECKING             2
# 20172               953     CHECKING             2
# 20346               965     CHECKING             2
#
# [66 rows x 3 columns]

# %%
acctDF[acctDF["prism_consumer_id"] == "1147"]
# Out:
#      prism_consumer_id prism_account_id account_type balance_date  balance
# 5783              1147             5783      SAVINGS   2021-09-30     0.00
# 5784              1147             5784     CHECKING   2021-09-29   632.77
# 5785              1147             5785     CHECKING   2021-09-30     0.00

# %%
earliest_balances = (
    acctDF
    .sort_values("balance_date")
    .groupby(["prism_consumer_id", "account_type"], as_index=False)
    .first()
)

# %%
earliest_balances
# Out:
#       prism_consumer_id account_type prism_account_id balance_date  balance
# 0                     0     CHECKING              863   2021-08-31   294.67
# 1                     0      SAVINGS              862   2021-08-31    25.70
# 2                     1     CHECKING             7755   2021-06-30    91.24
# 3                     1      SAVINGS             7754   2021-06-30  3211.18
# 4                    10     CHECKING             1499   2022-01-31   822.75
# ...                 ...          ...              ...          ...      ...
# 20866              9995     CHECKING            16037   2023-03-02     0.00
# 20867              9996     CHECKING            11265   2023-10-11   252.67
# 20868              9997     CHECKING            12268   2023-05-25   611.28
# 20869              9998     CHECKING            10607   2023-11-02  -862.99
# 20870              9999     CHECKING             9506   2023-08-09    -9.02
#
# [20871 rows x 5 columns]

# %%
starting_balances = earliest_balances.pivot(
    index="prism_consumer_id",
    columns="account_type",
    values="balance"
).reset_index()

# %%
starting_balances
# Out:
# account_type prism_consumer_id  401K  AUTO  BROKERAGE  CASH MANAGEMENT  CD  \
# 0                            0   NaN   NaN        NaN              NaN NaN
# 1                            1   NaN   NaN        NaN              NaN NaN
# 2                           10   NaN   NaN        NaN              NaN NaN
# 3                          100   NaN   NaN        NaN              NaN NaN
# 4                         1000   NaN   NaN        NaN              NaN NaN
# ...                        ...   ...   ...        ...              ...  ..
# 13004                     9995   NaN   NaN        NaN              NaN NaN
# 13005                     9996   NaN   NaN        NaN              NaN NaN
# 13006                     9997   NaN   NaN        NaN              NaN NaN
# 13007                     9998   NaN   NaN        NaN              NaN NaN
# 13008                     9999   NaN   NaN        NaN              NaN NaN
#
# account_type  CHECKING  CONSUMER  CREDIT CARD  HOME EQUITY  ...  MONEYMARKET  \
# 0               294.67       NaN          NaN          NaN  ...          NaN
# 1                91.24       NaN          NaN          NaN  ...          NaN
# 2               822.75       NaN          NaN          NaN  ...          NaN
# 3               802.40       NaN          NaN          NaN  ...          NaN
# 4                95.23       NaN          NaN          NaN  ...          NaN
# ...                ...       ...          ...          ...  ...          ...
# 13004             0.00       NaN          NaN          NaN  ...          NaN
# 13005           252.67       NaN          NaN          NaN  ...          NaN
# 13006           611.28       NaN          NaN          NaN  ...          NaN
# 13007          -862.99       NaN          NaN          NaN  ...          NaN
# 13008            -9.02       NaN          NaN          NaN  ...          NaN
#
# account_type  MORTGAGE  OTHER  OVERDRAFT  PREPAID  RETIREMENT  ROTH  SAVINGS  \
# 0                  NaN    NaN        NaN      NaN         NaN   NaN    25.70
# 1                  NaN    NaN        NaN      NaN         NaN   NaN  3211.18
# 2                  NaN    NaN        NaN      NaN         NaN   NaN     1.49
# 3                  NaN    NaN        NaN      NaN         NaN   NaN  1853.07
# 4                  NaN    NaN        NaN      NaN         NaN   NaN     0.02
# ...                ...    ...        ...      ...         ...   ...      ...
# 13004              NaN    NaN        NaN      NaN         NaN   NaN      NaN
# 13005              NaN    NaN        NaN      NaN         NaN   NaN      NaN
# 13006              NaN    NaN        NaN      NaN         NaN   NaN      NaN
# 13007              NaN    NaN        NaN      NaN         NaN   NaN      NaN
# 13008              NaN    NaN        NaN      NaN         NaN   NaN      NaN
#
# account_type  STOCK PLAN  STUDENT
# 0                    NaN      NaN
# 1                    NaN      NaN
# 2                    NaN      NaN
# 3                    NaN      NaN
# 4                    NaN      NaN
# ...                  ...      ...
# 13004                NaN      NaN
# 13005                NaN      NaN
# 13006                NaN      NaN
# 13007                NaN      NaN
# 13008                NaN      NaN
#
# [13009 rows x 25 columns]

# %%
starting_balances["initial_total_balance"] = (
    starting_balances[["SAVINGS", "CHECKING"]].sum(axis=1)
)
starting_balances
# Out:
# account_type prism_consumer_id  401K  AUTO  BROKERAGE  CASH MANAGEMENT  CD  \
# 0                            0   NaN   NaN        NaN              NaN NaN
# 1                            1   NaN   NaN        NaN              NaN NaN
# 2                           10   NaN   NaN        NaN              NaN NaN
# 3                          100   NaN   NaN        NaN              NaN NaN
# 4                         1000   NaN   NaN        NaN              NaN NaN
# ...                        ...   ...   ...        ...              ...  ..
# 13004                     9995   NaN   NaN        NaN              NaN NaN
# 13005                     9996   NaN   NaN        NaN              NaN NaN
# 13006                     9997   NaN   NaN        NaN              NaN NaN
# 13007                     9998   NaN   NaN        NaN              NaN NaN
# 13008                     9999   NaN   NaN        NaN              NaN NaN
#
# account_type  CHECKING  CONSUMER  CREDIT CARD  HOME EQUITY  ...  MORTGAGE  \
# 0               294.67       NaN          NaN          NaN  ...       NaN
# 1                91.24       NaN          NaN          NaN  ...       NaN
# 2               822.75       NaN          NaN          NaN  ...       NaN
# 3               802.40       NaN          NaN          NaN  ...       NaN
# 4                95.23       NaN          NaN          NaN  ...       NaN
# ...                ...       ...          ...          ...  ...       ...
# 13004             0.00       NaN          NaN          NaN  ...       NaN
# 13005           252.67       NaN          NaN          NaN  ...       NaN
# 13006           611.28       NaN          NaN          NaN  ...       NaN
# 13007          -862.99       NaN          NaN          NaN  ...       NaN
# 13008            -9.02       NaN          NaN          NaN  ...       NaN
#
# account_type  OTHER  OVERDRAFT  PREPAID  RETIREMENT  ROTH  SAVINGS  \
# 0               NaN        NaN      NaN         NaN   NaN    25.70
# 1               NaN        NaN      NaN         NaN   NaN  3211.18
# 2               NaN        NaN      NaN         NaN   NaN     1.49
# 3               NaN        NaN      NaN         NaN   NaN  1853.07
# 4               NaN        NaN      NaN         NaN   NaN     0.02
# ...             ...        ...      ...         ...   ...      ...
# 13004           NaN        NaN      NaN         NaN   NaN      NaN
# 13005           NaN        NaN      NaN         NaN   NaN      NaN
# 13006           NaN        NaN      NaN         NaN   NaN      NaN
# 13007           NaN        NaN      NaN         NaN   NaN      NaN
# 13008           NaN        NaN      NaN         NaN   NaN      NaN
#
# account_type  STOCK PLAN  STUDENT  initial_total_balance
# 0                    NaN      NaN                 320.37
# 1                    NaN      NaN                3302.42
# 2                    NaN      NaN                 824.24
# 3                    NaN      NaN                2655.47
# 4                    NaN      NaN                  95.25
# ...                  ...      ...                    ...
# 13004                NaN      NaN                   0.00
# 13005                NaN      NaN                 252.67
# 13006                NaN      NaN                 611.28
# 13007                NaN      NaN                -862.99
# 13008                NaN      NaN                  -9.02
#
# [13009 rows x 26 columns]

# %%
starting_dates = earliest_balances.pivot(
    index="prism_consumer_id",
    columns="account_type",
    values="balance_date"
).reset_index()
starting_dates
# Out:
# account_type prism_consumer_id 401K AUTO BROKERAGE CASH MANAGEMENT  CD  \
# 0                            0  NaT  NaT       NaT             NaT NaT
# 1                            1  NaT  NaT       NaT             NaT NaT
# 2                           10  NaT  NaT       NaT             NaT NaT
# 3                          100  NaT  NaT       NaT             NaT NaT
# 4                         1000  NaT  NaT       NaT             NaT NaT
# ...                        ...  ...  ...       ...             ...  ..
# 13004                     9995  NaT  NaT       NaT             NaT NaT
# 13005                     9996  NaT  NaT       NaT             NaT NaT
# 13006                     9997  NaT  NaT       NaT             NaT NaT
# 13007                     9998  NaT  NaT       NaT             NaT NaT
# 13008                     9999  NaT  NaT       NaT             NaT NaT
#
# account_type   CHECKING CONSUMER CREDIT CARD HOME EQUITY  ... MONEYMARKET  \
# 0            2021-08-31      NaT         NaT         NaT  ...         NaT
# 1            2021-06-30      NaT         NaT         NaT  ...         NaT
# 2            2022-01-31      NaT         NaT         NaT  ...         NaT
# 3            2021-04-30      NaT         NaT         NaT  ...         NaT
# 4            2023-01-31      NaT         NaT         NaT  ...         NaT
# ...                 ...      ...         ...         ...  ...         ...
# 13004        2023-03-02      NaT         NaT         NaT  ...         NaT
# 13005        2023-10-11      NaT         NaT         NaT  ...         NaT
# 13006        2023-05-25      NaT         NaT         NaT  ...         NaT
# 13007        2023-11-02      NaT         NaT         NaT  ...         NaT
# 13008        2023-08-09      NaT         NaT         NaT  ...         NaT
#
# account_type MORTGAGE OTHER OVERDRAFT PREPAID RETIREMENT ROTH    SAVINGS  \
# 0                 NaT   NaT       NaT     NaT        NaT  NaT 2021-08-31
# 1                 NaT   NaT       NaT     NaT        NaT  NaT 2021-06-30
# 2                 NaT   NaT       NaT     NaT        NaT  NaT 2022-01-31
# 3                 NaT   NaT       NaT     NaT        NaT  NaT 2022-12-31
# 4                 NaT   NaT       NaT     NaT        NaT  NaT 2023-01-31
# ...               ...   ...       ...     ...        ...  ...        ...
# 13004             NaT   NaT       NaT     NaT        NaT  NaT        NaT
# 13005             NaT   NaT       NaT     NaT        NaT  NaT        NaT
# 13006             NaT   NaT       NaT     NaT        NaT  NaT        NaT
# 13007             NaT   NaT       NaT     NaT        NaT  NaT        NaT
# 13008             NaT   NaT       NaT     NaT        NaT  NaT        NaT
#
# account_type STOCK PLAN STUDENT
# 0                   NaT     NaT
# 1                   NaT     NaT
# 2                   NaT     NaT
# 3                   NaT     NaT
# 4                   NaT     NaT
# ...                 ...     ...
# 13004               NaT     NaT
# 13005               NaT     NaT
# 13006               NaT     NaT
# 13007               NaT     NaT
# 13008               NaT     NaT
#
# [13009 rows x 25 columns]

# %%
trxnDF["posted_date"] = pd.to_datetime(trxnDF["posted_date"])

trxnDF["signed_amount"] = trxnDF["amount"].where(
    trxnDF["credit_or_debit"] == "CREDIT",
    -trxnDF["amount"]
)

trxnDF = trxnDF.sort_values(
    ["prism_consumer_id", "posted_date"]
)
trxn_with_start = trxnDF.merge(
    starting_balances[["prism_consumer_id", "initial_total_balance"]],
    on="prism_consumer_id",
    how="left"
)
trxn_with_start["running_total_balance"] = (
    trxn_with_start
    .groupby("prism_consumer_id")["signed_amount"]
    .cumsum()
    + trxn_with_start["initial_total_balance"]
)

# %%
start_date = (
    earliest_balances
    .groupby("prism_consumer_id")["balance_date"]
    .min()
    .reset_index(name="start_balance_date")
)
start_date
# Out:
#       prism_consumer_id start_balance_date
# 0                     0         2021-08-31
# 1                     1         2021-06-30
# 2                    10         2022-01-31
# 3                   100         2021-04-30
# 4                  1000         2023-01-31
# ...                 ...                ...
# 13004              9995         2023-03-02
# 13005              9996         2023-10-11
# 13006              9997         2023-05-25
# 13007              9998         2023-11-02
# 13008              9999         2023-08-09
#
# [13009 rows x 2 columns]

# %%
trxn_with_start = trxn_with_start.merge(
    start_date,
    on="prism_consumer_id",
    how="left"
)

# %%
trxn_with_start = trxn_with_start[
    trxn_with_start["posted_date"] >= trxn_with_start["start_balance_date"]
]

# %%
trxn_with_start[trxn_with_start["prism_consumer_id"] == "1911"]
# Out:
#         prism_consumer_id prism_transaction_id  category  amount  \
# 3788553              1911               711710         3  347.34
# 3788554              1911               712122         4   16.52
# 3788555              1911               711768         6    5.95
# 3788556              1911               712123        18   23.09
# 3788557              1911               712124        18   13.97
# ...                   ...                  ...       ...     ...
# 3788628              1911               711776         4   18.98
# 3788629              1911               711777         1   28.56
# 3788630              1911               711813         1   18.98
# 3788631              1911               712179        17   33.00
# 3788632              1911               712180        16   22.06
#
#         credit_or_debit posted_date  signed_amount  initial_total_balance  \
# 3788553          CREDIT  2021-12-29         347.34               10044.36
# 3788554           DEBIT  2021-12-30         -16.52               10044.36
# 3788555          CREDIT  2021-12-31           5.95               10044.36
# 3788556           DEBIT  2021-12-31         -23.09               10044.36
# 3788557           DEBIT  2022-01-01         -13.97               10044.36
# ...                 ...         ...            ...                    ...
# 3788628          CREDIT  2022-01-26          18.98               10044.36
# 3788629          CREDIT  2022-01-26          28.56               10044.36
# 3788630           DEBIT  2022-01-26         -18.98               10044.36
# 3788631           DEBIT  2022-01-26         -33.00               10044.36
# 3788632           DEBIT  2022-01-26         -22.06               10044.36
#
#          running_total_balance start_balance_date
# 3788553                9554.85         2021-12-29
# 3788554                9538.33         2021-12-29
# 3788555                9544.28         2021-12-29
# 3788556                9521.19         2021-12-29
# 3788557                9507.22         2021-12-29
# ...                        ...                ...
# 3788628                7022.85         2021-12-29
# 3788629                7051.41         2021-12-29
# 3788630                7032.43         2021-12-29
# 3788631                6999.43         2021-12-29
# 3788632                6977.37         2021-12-29
#
# [80 rows x 10 columns]

# %%
trxn_with_dq = trxn_with_start.merge(
    consDF[["prism_consumer_id", "DQ_TARGET"]],
    on="prism_consumer_id",
    how="inner"
)
sampled_consumers = (
    trxn_with_dq[["prism_consumer_id", "DQ_TARGET"]]
    .drop_duplicates()
    .groupby("DQ_TARGET", group_keys=False)
    .apply(lambda x: x.sample(n=5, random_state=42))
)

sampled_consumers
# Out:
# /tmp/ipykernel_258/2089267460.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(n=5, random_state=42))
#        prism_consumer_id  DQ_TARGET
# 9664               12346        0.0
# 39303               1911        0.0
# 156369              8362        0.0
# 139715              5964        0.0
# 125208                39        0.0
# 158180              8669        1.0
# 127127              3961        1.0
# 149210              7374        1.0
# 140190              6021        1.0
# 150464              7563        1.0

# %%
sample_ids = sampled_consumers["prism_consumer_id"]

plot_df = trxn_with_start[
    trxn_with_start["prism_consumer_id"].isin(sample_ids)
].merge(
    sampled_consumers[["prism_consumer_id", "DQ_TARGET"]],
    on="prism_consumer_id",
    how="left"
)

# %%
plt.figure(figsize=(10,6))

for cid, g in plot_df.groupby("prism_consumer_id"):
    dq = g["DQ_TARGET"].iloc[0]
    color = "tab:orange" if dq == 1 else "tab:blue"

    plt.plot(
        g["posted_date"],
        g["running_total_balance"],
        alpha=0.8,
        color=color
    )

plt.xlabel("Date")
plt.ylabel("Running Total Balance")
plt.title("Running Balance Over Time (Sampled Consumers)")
plt.show()

# %%
plot_df
# Out:
#     prism_consumer_id prism_transaction_id  category  amount credit_or_debit  \
# 0               12346              4027494        40   17.11           DEBIT
# 1               12346              4027495        17   20.98           DEBIT
# 2               12346              4027496        21   75.00           DEBIT
# 3               12346              4027497        17   18.99           DEBIT
# 4                1911               711710         3  347.34          CREDIT
# ..                ...                  ...       ...     ...             ...
# 139              8669              1655459        20   94.97           DEBIT
# 140              8669              1655460        14   40.38           DEBIT
# 141              8669              1655461         1  130.00           DEBIT
# 142              8669              1655462        18    1.99           DEBIT
# 143              8669              1655463         4   38.00           DEBIT
#
#     posted_date  signed_amount  initial_total_balance  running_total_balance  \
# 0    2022-03-31         -17.11                 994.81                1974.89
# 1    2022-03-31         -20.98                 994.81                1953.91
# 2    2022-03-31         -75.00                 994.81                1878.91
# 3    2022-03-31         -18.99                 994.81                1859.92
# 4    2021-12-29         347.34               10044.36                9554.85
# ..          ...            ...                    ...                    ...
# 139  2023-05-11         -94.97                1618.95                3005.36
# 140  2023-05-11         -40.38                1618.95                2964.98
# 141  2023-05-11        -130.00                1618.95                2834.98
# 142  2023-05-11          -1.99                1618.95                2832.99
# 143  2023-05-11         -38.00                1618.95                2794.99
#
#     start_balance_date  DQ_TARGET
# 0           2022-03-31        0.0
# 1           2022-03-31        0.0
# 2           2022-03-31        0.0
# 3           2022-03-31        0.0
# 4           2021-12-29        0.0
# ..                 ...        ...
# 139         2023-05-11        1.0
# 140         2023-05-11        1.0
# 141         2023-05-11        1.0
# 142         2023-05-11        1.0
# 143         2023-05-11        1.0
#
# [144 rows x 11 columns]
