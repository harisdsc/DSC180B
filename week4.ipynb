# %%
import pandas as pd
import numpy as np

consDF = pd.read_parquet("/uss/hdsi-prismdata/q2-ucsd-consDF.pqt")
consDF = consDF.drop(columns = ["credit_score"])
testDF = consDF[consDF['DQ_TARGET'].isna()]
consDF = consDF.dropna()
acctDF = pd.read_parquet("/uss/hdsi-prismdata/q2-ucsd-acctDF.pqt")
acctDF = acctDF[acctDF["prism_consumer_id"].isin(consDF['prism_consumer_id'])]
trxnDF = pd.read_parquet("/uss/hdsi-prismdata/q2-ucsd-trxnDF.pqt")
trxnDF = trxnDF[trxnDF["prism_consumer_id"].isin(consDF['prism_consumer_id'])]
catmap = pd.read_csv("/uss/hdsi-prismdata/q2-ucsd-cat-map.csv")

# %%
income_cats = [2,3,5,7,8,9,49]
windows = [1,3,6,9]
categories = catmap['category_id'].unique()

# def consumer_agg(
#     df: pd.DataFrame,
#     group_col: str,
#     feat_col: str,
#     window: int,
#     label: str,
#     stats=("mean", "median", "std", "min", "max"),
#     prefix_map=None,
# ) -> pd.DataFrame:
#     """
#     Generic consumer-level aggregation for a single feature column.

#     Example output columns:
#       avg_6m_netflow, med_6m_netflow, sd_6m_netflow, ...

#     Parameters
#     ----------
#     df : DataFrame
#         Must contain group_col and feat_col
#     group_col : str
#         Consumer id
#     feat_col : str
#         Column to aggregate (e.g. 'net_flow_6m')
#     window : int
#         Rolling window length (used for naming)
#     stats : tuple[str]
#         Aggregations to compute
#     prefix_map : dict[str,str]
#         Optional mapping: {"mean":"avg","median":"med","std":"sd","min":"min","max":"max"}
#     """
#     if prefix_map is None:
#         prefix_map = {"mean":"avg","median":"med","std":"sd","min":"min","max":"max"}

#     agg_spec = {f"{prefix_map[s]}_{window}m_{label}": (feat_col, s) for s in stats}

#     return df.groupby(group_col, as_index=False).agg(**agg_spec)

def consumer_agg(
    df: pd.DataFrame,
    group_col: str,
    feat_cols: list[str],
    stats=("mean", "median", "std", "min", "max"),
    prefix_map=None,
    # optional "single-feature pretty naming"
    window = windows,
    label: str | None = None,
) -> pd.DataFrame:
    """
    Consumer-level aggregation.

    Two modes:

    A) Multi-feature mode (default):
       feat_cols = ["x_3m", "y_3m"]  ->
         avg_x_3m, med_x_3m, sd_x_3m, min_x_3m, max_x_3m,
         avg_y_3m, ...

    B) Single-feature pretty naming:
       feat_cols = ["net_flow_6m"], window=6, label="netflow" ->
         avg_6m_netflow, med_6m_netflow, sd_6m_netflow, min_6m_netflow, max_6m_netflow
    """
    if prefix_map is None:
        prefix_map = {"mean": "avg", "median": "med", "std": "sd", "min": "min", "max": "max"}

    feat_cols = list(feat_cols)

    missing = [c for c in feat_cols if c not in df.columns]
    if missing:
        raise KeyError(f"consumer_agg: missing columns in df: {missing}")

    agg_spec = {}

    single_pretty = (window is not None) and (label is not None) and (len(feat_cols) == 1)
    if single_pretty:
        c = feat_cols[0]
        for s in stats:
            agg_spec[f"{prefix_map.get(s, s)}_{int(window)}m_{label}"] = (c, s)
    else:
        for c in feat_cols:
            for s in stats:
                agg_spec[f"{prefix_map.get(s, s)}_{c}"] = (c, s)

    return df.groupby(group_col, as_index=False).agg(**agg_spec)


def build_monthly_cashflows(
    txn_df: pd.DataFrame,
    window: int,
    income_cats,
    date_col="posted_date",
    amt_col="amount",
    consumer_col="prism_consumer_id",
    cd_col="credit_or_debit",
    cat_col="category",
    fill_months=True,
    min_periods=None,
    return_consumer_level=False,
):
    """
    Builds monthly income/spend and rolling net flow features.

    Fixes:
      - avoids groupby.apply DeprecationWarning via include_groups=False
      - avoids risky reindex(fill_value=0.0) by only filling numeric columns
      - normalizes CREDIT/DEBIT casing
    """
    w = int(window)
    if min_periods is None:
        min_periods = w

    df = txn_df.copy()
    df[date_col] = pd.to_datetime(df[date_col], errors="coerce")
    df = df.dropna(subset=[date_col, consumer_col])
    df = df.sort_values([consumer_col, date_col])

    df["month"] = df[date_col].dt.to_period("M").dt.to_timestamp()

    # normalize CREDIT/DEBIT
    dir_upper = df[cd_col].astype(str).str.upper()

    df[amt_col] = pd.to_numeric(df[amt_col], errors="coerce")
    df = df.dropna(subset=[amt_col])

    df["income_amt"] = np.where(
        (dir_upper == "CREDIT") & (df[cat_col].isin(income_cats)),
        df[amt_col].astype(float),
        0.0,
    )
    df["spend_amt"] = np.where(
        (dir_upper == "DEBIT"),
        df[amt_col].astype(float),
        0.0,
    )

    monthly = (
        df.groupby([consumer_col, "month"], as_index=False)
          .agg(income=("income_amt", "sum"),
               spend=("spend_amt", "sum"))
          .sort_values([consumer_col, "month"])
          .reset_index(drop=True)
    )

    # --- fill missing months within each consumer (safe fill) ---
    if fill_months and not monthly.empty:
        fill_cols = ["income", "spend"]
    
        def _fill(g: pd.DataFrame) -> pd.DataFrame:
            cid = g.name  # <-- group key (consumer id) when include_groups=False
            full = pd.date_range(g["month"].min(), g["month"].max(), freq="MS")
    
            g2 = (
                g.set_index("month")
                 .reindex(full)
                 .rename_axis("month")
                 .reset_index()
            )
    
            g2[consumer_col] = cid
    
            for c in fill_cols:
                if c not in g2.columns:
                    g2[c] = 0.0
            g2[fill_cols] = g2[fill_cols].fillna(0.0)
    
            return g2
    
        monthly = (
            monthly
            .groupby(consumer_col, group_keys=False)
            .apply(_fill, include_groups=False)
            .sort_values([consumer_col, "month"])
            .reset_index(drop=True)
        )


    # --- rolling features ---
    g = monthly.groupby(consumer_col, group_keys=False)

    if w == 1:
        monthly["income_1m"] = monthly["income"]
        monthly["spend_1m"] = monthly["spend"]
        monthly["net_flow_1m"] = monthly["income_1m"] - monthly["spend_1m"]
        feat_col = "net_flow_1m"
    else:
        monthly[f"income_{w}m"] = g["income"].transform(lambda s: s.rolling(w, min_periods=min_periods).sum())
        monthly[f"spend_{w}m"]  = g["spend"].transform(lambda s: s.rolling(w, min_periods=min_periods).sum())
        monthly[f"net_flow_{w}m"] = monthly[f"income_{w}m"] - monthly[f"spend_{w}m"]
        feat_col = f"net_flow_{w}m"

    if not return_consumer_level:
        return monthly

    return consumer_agg(
        df=monthly,
        group_col=consumer_col,
        feat_cols=[feat_col],
        window=w,
        label="netflow",
    )

# %%
# monthly 1m table
m1 = build_monthly_cashflows(
    trxnDF,
    window=1,
    income_cats=income_cats,
    return_consumer_level=False
)

# base consumer totals
netflow_feats = (
    m1.groupby("prism_consumer_id", as_index=False)
      .agg(
          months_observed=("month", "nunique"),
          total_income=("income_1m", "sum"),
          total_spend=("spend_1m", "sum"),
          total_net_flow=("net_flow_1m", "sum"),
      )
)

# add windowed consumer-level summary stats
for w in windows:
    cons_w = build_monthly_cashflows(
        trxnDF,
        window=w,
        income_cats=income_cats,
        return_consumer_level=True
    )
    netflow_feats = netflow_feats.merge(cons_w, on="prism_consumer_id", how="left")

netflow_feats
# Out:
#       prism_consumer_id  months_observed  total_income  total_spend  \
# 0                     0                7       9320.56     14908.41
# 1                     1                7      13411.59     23098.37
# 2                    10                7      15420.74     21766.60
# 3                   100                6      24411.78     39742.61
# 4                  1000                7      48378.60     77914.99
# ...                 ...              ...           ...          ...
# 11596               995                7      36558.09     31466.47
# 11597               996                7       4107.21    196249.61
# 11598               997                7      33797.46     81076.60
# 11599               998                7      38813.02     66207.01
# 11600               999                7      18184.26     25970.02
#
#        total_net_flow  avg_1m_netflow  med_1m_netflow  sd_1m_netflow  \
# 0            -5587.85     -798.264286        -212.560    1363.160352
# 1            -9686.78    -1383.825714       -1039.490    1234.856462
# 2            -6345.86     -906.551429        -978.850     601.382838
# 3           -15330.83    -2555.138333       -2087.665    2408.512923
# 4           -29536.39    -4219.484286        -618.080    7192.050945
# ...               ...             ...             ...            ...
# 11596         5091.62      727.374286        1065.550    2194.693702
# 11597      -192142.40   -27448.914286      -26736.070   15990.433902
# 11598       -47279.14    -6754.162857       -6003.820    2024.975140
# 11599       -27393.99    -3913.427143       -2019.060    5029.301050
# 11600        -7785.76    -1112.251429        -900.450    1413.417799
#
#        min_1m_netflow  max_1m_netflow  ...  avg_6m_netflow  med_6m_netflow  \
# 0            -3466.67          513.28  ...       -5344.925       -5344.925
# 1            -3232.42           79.83  ...       -8209.595       -8209.595
# 2            -1915.14         -197.84  ...       -5633.285       -5633.285
# 3            -5515.09          624.68  ...      -15330.830      -15330.830
# 4           -18367.94         1348.32  ...      -28927.255      -28927.255
# ...               ...             ...  ...             ...             ...
# 11596        -3745.92         3036.70  ...        4245.425        4245.425
# 11597       -56765.29        -7395.93  ...     -171790.530     -171790.530
# 11598       -10818.18        -4970.93  ...      -41756.060      -41756.060
# 11599       -11758.49          560.53  ...      -22484.075      -22484.075
# 11600        -3815.24          364.69  ...       -6554.100       -6554.100
#
#        sd_6m_netflow  min_6m_netflow  max_6m_netflow  avg_9m_netflow  \
# 0        1069.435367        -6101.13        -4588.72             NaN
# 1        1732.715670        -9434.81        -6984.38             NaN
# 2         535.117199        -6011.67        -5254.90             NaN
# 3                NaN       -15330.83       -15330.83             NaN
# 4          12.650140       -28936.20       -28918.31             NaN
# ...              ...             ...             ...             ...
# 11596     310.214816         4026.07         4464.78             NaN
# 11597   18322.466061      -184746.47      -158834.59             NaN
# 11598     167.867150       -41874.76       -41637.36             NaN
# 11599    7736.377511       -27954.52       -17013.63             NaN
# 11600     876.741698        -7174.05        -5934.15             NaN
#
#        med_9m_netflow  sd_9m_netflow  min_9m_netflow  max_9m_netflow
# 0                 NaN            NaN             NaN             NaN
# 1                 NaN            NaN             NaN             NaN
# 2                 NaN            NaN             NaN             NaN
# 3                 NaN            NaN             NaN             NaN
# 4                 NaN            NaN             NaN             NaN
# ...               ...            ...             ...             ...
# 11596             NaN            NaN             NaN             NaN
# 11597             NaN            NaN             NaN             NaN
# 11598             NaN            NaN             NaN             NaN
# 11599             NaN            NaN             NaN             NaN
# 11600             NaN            NaN             NaN             NaN
#
# [11601 rows x 25 columns]

# %%
def build_monthly_category_to_income(
    txn_df: pd.DataFrame,
    income_cats,
    category_ids = categories,
    date_col: str = "posted_date",
    consumer_col: str = "prism_consumer_id",
    amt_col: str = "amount",
    direction_col: str = "credit_or_debit",
    category_col: str = "category",
    window=windows,
    fill_missing_months: bool = True,
    min_periods: int | None = None,
    consumer_level: bool = False,
    agg_stats=("mean", "median", "std", "min", "max"),
) -> pd.DataFrame:

    # --- normalize category_ids ---
    if isinstance(category_ids, (int, np.integer)):
        category_ids = [int(category_ids)]
    else:
        category_ids = [int(x) for x in category_ids]
    category_ids = sorted(set(category_ids))

    # --- prep txns ---
    t = txn_df[[date_col, consumer_col, amt_col, direction_col, category_col]].copy()
    t[date_col] = pd.to_datetime(t[date_col], errors="coerce")
    t = t.dropna(subset=[date_col, consumer_col])

    t[amt_col] = pd.to_numeric(t[amt_col], errors="coerce")
    t = t.dropna(subset=[amt_col])

    t["month"] = t[date_col].dt.to_period("M").dt.to_timestamp()

    dir_upper = t[direction_col].astype(str).str.upper()
    is_credit = dir_upper.eq("CREDIT")
    is_debit  = dir_upper.eq("DEBIT")

    income_cats_set = set(int(x) for x in income_cats)

    # --- monthly income ---
    income_m = (
        t.loc[is_credit & t[category_col].isin(income_cats_set)]
         .groupby([consumer_col, "month"], as_index=False)[amt_col]
         .sum()
         .rename(columns={amt_col: "income_1m"})
    )

    # --- monthly spend for requested categories (all at once) ---
    spend_1m_cols = [f"cat{cid}_spend_1m" for cid in category_ids]

    spend_m = (
        t.loc[is_debit & t[category_col].isin(category_ids)]
         .groupby([consumer_col, "month", category_col])[amt_col]
         .sum()
         .unstack(category_col)
    )

    if not spend_m.empty:
        spend_m = spend_m.reindex(columns=category_ids)  # stable order + include missing cats
        spend_m.columns = spend_1m_cols
        spend_m = spend_m.reset_index()
    else:
        spend_m = pd.DataFrame(columns=[consumer_col, "month"] + spend_1m_cols)

    # --- base (one merge) ---
    base = income_m.merge(spend_m, on=[consumer_col, "month"], how="outer")

    if base.empty:
        cols = [consumer_col, "month", "income_1m"] + spend_1m_cols
        return pd.DataFrame(columns=cols)

    base = base.sort_values([consumer_col, "month"]).reset_index(drop=True)

    # fill missing monthly values
    base["income_1m"] = base["income_1m"].fillna(0.0)
    for c in spend_1m_cols:
        if c not in base.columns:
            base[c] = 0.0
    base[spend_1m_cols] = base[spend_1m_cols].fillna(0.0)

    # --- fill missing months within each consumer (no .name / no include_groups needed) ---
    if fill_missing_months and not base.empty:
        fill_cols = ["income_1m"] + spend_1m_cols

        spans = (
            base.groupby(consumer_col, as_index=False)["month"]
                .agg(min_month="min", max_month="max")
        )
        spans["month"] = spans.apply(
            lambda r: pd.date_range(r["min_month"], r["max_month"], freq="MS"),
            axis=1
        )
        grid = spans[[consumer_col, "month"]].explode("month", ignore_index=True)

        base = grid.merge(base, on=[consumer_col, "month"], how="left")

        for c in fill_cols:
            if c not in base.columns:
                base[c] = 0.0
        base[fill_cols] = base[fill_cols].fillna(0.0)

        base = base.sort_values([consumer_col, "month"]).reset_index(drop=True)

    # --- rolling features ---
    gb = base.groupby(consumer_col, group_keys=False)
    frames = []

    # (A) If window includes 1: only create ratio_1m (DON'T re-add income_1m/spend_1m)
    if 1 in set(int(w) for w in window):
        denom_1m = base["income_1m"].replace(0, np.nan)
        ratio_1m = base[spend_1m_cols].div(denom_1m, axis=0).rename(
            columns=lambda c: c.replace("_spend_1m", "_to_income_ratio_1m")
        )
        frames.append(ratio_1m)

    # (B) W > 1: create income_Wm, spend_Wm, ratio_Wm
    for W in [int(w) for w in window if int(w) != 1]:
        mp = W if min_periods is None else int(min_periods)

        income_roll = gb["income_1m"].transform(lambda s: s.rolling(W, min_periods=mp).sum())
        denom = income_roll.replace(0, np.nan)

        spend_roll = gb[spend_1m_cols].transform(lambda df: df.rolling(W, min_periods=mp).sum())
        spend_roll = spend_roll.rename(columns=lambda c: c.replace("_spend_1m", f"_spend_{W}m"))

        ratio = spend_roll.div(denom, axis=0).rename(
            columns=lambda c: c.replace("_spend_", "_to_income_ratio_")
        )

        frames.append(pd.concat([income_roll.rename(f"income_{W}m"), spend_roll, ratio], axis=1))

    base = pd.concat([base] + frames, axis=1).copy()

    # --- return monthly or consumer-level ---
    if not consumer_level:
        return base

    agg_cols = []
    for cat_id in category_ids:
        label = f"cat{cat_id}"
        for W in [int(w) for w in window]:
            agg_cols.extend([
                f"{label}_spend_{W}m" if W != 1 else f"{label}_spend_1m",
                f"{label}_to_income_ratio_{W}m",
            ])

    return consumer_agg(
        df=base,
        group_col=consumer_col,
        feat_cols=agg_cols,
        stats=agg_stats,
    )

# %%
# monthly = build_monthly_category_to_income(
#     txn_df=trxnDF,
#     category_ids=[18, 20],
#     income_cats=income_cats,
#     window=(3, 6),
#     consumer_level=False,
# )

cat_ratio_feats = build_monthly_category_to_income(
    txn_df=trxnDF,
    income_cats=income_cats,
    # category_ids=[18, 20],
    # window=[1,3],
    consumer_level=True,
)
# Out:
# /tmp/ipykernel_1891/3574960033.py:87: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   return df.groupby(group_col, as_index=False).agg(**agg_spec)

# %%
# monthly

# %%
cat_ratio_feats
# Out:
#       prism_consumer_id  avg_cat0_spend_1m  med_cat0_spend_1m  \
# 0                     0          67.338571              43.64
# 1                     1        1300.428571            1065.00
# 2                    10         271.507143             230.00
# 3                   100        1992.113333            1860.16
# 4                  1000        7054.987143            4546.66
# ...                 ...                ...                ...
# 11511               995           0.148571               0.00
# 11512               996       11337.808571           11500.00
# 11513               997        4655.654286            4843.70
# 11514               998        2689.627143             900.00
# 11515               999         146.801429              83.00
#
#        sd_cat0_spend_1m  min_cat0_spend_1m  max_cat0_spend_1m  \
# 0             61.742993              10.00             176.44
# 1            696.831605             569.00            2619.00
# 2            273.997385               0.00             600.55
# 3            969.847252            1101.88            3160.16
# 4           7569.116043            1000.00           22899.63
# ...                 ...                ...                ...
# 11511          0.393083               0.00               1.04
# 11512       8273.802795               0.00           23971.42
# 11513       1034.651032            2454.07            5559.99
# 11514       3106.537795               0.00            7657.39
# 11515        198.470340              10.00             578.00
#
#        avg_cat0_to_income_ratio_1m  med_cat0_to_income_ratio_1m  \
# 0                         0.097667                     0.045144
# 1                         0.753606                     0.584402
# 2                         0.141775                     0.068539
# 3                         0.527689                     0.442395
# 4                         1.046170                     0.702107
# ...                            ...                          ...
# 11511                     0.000018                     0.000000
# 11512                     1.625856                     1.625856
# 11513                     2.388590                     1.027782
# 11514                     0.650571                     0.125355
# 11515                     0.050175                     0.043684
#
#        sd_cat0_to_income_ratio_1m  min_cat0_to_income_ratio_1m  ...  \
# 0                        0.163582                     0.009998  ...
# 1                        0.506534                     0.301338  ...
# 2                        0.160186                     0.000000  ...
# 3                        0.341886                     0.251854  ...
# 4                        0.784976                     0.265232  ...
# ...                           ...                          ...  ...
# 11511                    0.000046                     0.000000  ...
# 11512                    2.299308                     0.000000  ...
# 11513                    3.816735                     0.584379  ...
# 11514                    0.980806                     0.000000  ...
# 11515                    0.043400                     0.014785  ...
#
#        avg_cat49_spend_9m  med_cat49_spend_9m  sd_cat49_spend_9m  \
# 0                     NaN                 NaN                NaN
# 1                     NaN                 NaN                NaN
# 2                     NaN                 NaN                NaN
# 3                     NaN                 NaN                NaN
# 4                     NaN                 NaN                NaN
# ...                   ...                 ...                ...
# 11511                 NaN                 NaN                NaN
# 11512                 NaN                 NaN                NaN
# 11513                 NaN                 NaN                NaN
# 11514                 NaN                 NaN                NaN
# 11515                 NaN                 NaN                NaN
#
#        min_cat49_spend_9m  max_cat49_spend_9m  avg_cat49_to_income_ratio_9m  \
# 0                     NaN                 NaN                           NaN
# 1                     NaN                 NaN                           NaN
# 2                     NaN                 NaN                           NaN
# 3                     NaN                 NaN                           NaN
# 4                     NaN                 NaN                           NaN
# ...                   ...                 ...                           ...
# 11511                 NaN                 NaN                           NaN
# 11512                 NaN                 NaN                           NaN
# 11513                 NaN                 NaN                           NaN
# 11514                 NaN                 NaN                           NaN
# 11515                 NaN                 NaN                           NaN
#
#        med_cat49_to_income_ratio_9m  sd_cat49_to_income_ratio_9m  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 11511                           NaN                          NaN
# 11512                           NaN                          NaN
# 11513                           NaN                          NaN
# 11514                           NaN                          NaN
# 11515                           NaN                          NaN
#
#        min_cat49_to_income_ratio_9m  max_cat49_to_income_ratio_9m
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
# ...                             ...                           ...
# 11511                           NaN                           NaN
# 11512                           NaN                           NaN
# 11513                           NaN                           NaN
# 11514                           NaN                           NaN
# 11515                           NaN                           NaN
#
# [11516 rows x 2001 columns]

# %%
mean_impute = netflow_feats.merge(cat_ratio_feats, on = 'prism_consumer_id')
# mean impute

# sd_cols = [c for c in mean_impute.columns if c.startswith("sd_")]
# mean_impute[sd_cols] = mean_impute[sd_cols].fillna(0.0)

# # print(sum(feats['min_3m_netflow'].isna()))
# for w in windows:
#     # ratio_cols = [c for c in mean_impute.columns if f'_{w}m_' in c]
#     for c in mean_impute.columns:
#         mean_impute[c] = mean_impute[c].fillna(mean_impute[c].mean())
# # print(sum(feats['min_3m_netflow'].isna()))

for c in mean_impute.columns:
    if c != 'prism_consumer_id':
        mean_impute[c] = mean_impute[c].fillna(mean_impute[c].mean())

mean_impute = consDF.merge(mean_impute, on = 'prism_consumer_id')
y = mean_impute['DQ_TARGET']

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~`
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

auc_df = pd.DataFrame()

feature_cols = mean_impute.drop(
    columns=["prism_consumer_id", "DQ_TARGET", "evaluation_date"]
)

for col in feature_cols.columns:
    X = feature_cols[[col]]
    y = y
    
    model = LogisticRegression(class_weight='balanced')
    model.fit(X, y)
    
    preds = model.predict_proba(X)[:, 1]
    
    score = roc_auc_score(y, preds)

    auc_df = pd.concat([auc_df, pd.DataFrame([{"feature": col, "auc_roc_mean": score}])],ignore_index=True)
    # print(col)
    # print(score)

# auc_df

# %%
# med_impute = netflow_feats.merge(cat_ratio_feats, on = 'prism_consumer_id')
# # median impute

# # sd_cols = [c for c in med_impute.columns if c.startswith("sd_")]
# # med_impute[sd_cols] = med_impute[sd_cols].fillna(0.0)

# # # print(sum(feats['min_3m_netflow'].isna()))
# # for w in windows:
# #     # ratio_cols = [c for c in med_impute.columns if f'_{w}m_' in c]
# #     for c in med_impute.columns:
# #         med_impute[c] = med_impute[c].fillna(med_impute[c].median())
# # # print(sum(feats['min_3m_netflow'].isna()))

# for c in med_impute.columns:
#     if c != 'prism_consumer_id':
#         med_impute[c] = med_impute[c].fillna(med_impute[c].median())

# med_impute = consDF.merge(med_impute, on = 'prism_consumer_id')
# y = med_impute['DQ_TARGET']

# # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~`
# feature_cols = med_impute.drop(
#     columns=["prism_consumer_id", "DQ_TARGET", "evaluation_date"]
# )

# temp_df = pd.DataFrame()
# for col in feature_cols.columns:
#     X = feature_cols[[col]]
#     y = y
    
#     model = LogisticRegression(class_weight='balanced')
#     model.fit(X, y)
    
#     preds = model.predict_proba(X)[:, 1]
    
#     score = roc_auc_score(y, preds)

#     temp_df = pd.concat([temp_df, pd.DataFrame([{"feature": col, "auc_roc_med": score}])],ignore_index=True)

# auc_df = auc_df.merge(temp_df, on='feature')
#     # auc_df = pd.concat([auc_df, pd.DataFrame([{"feature_med": col, "auc_roc_med": score}])],axis = 1,ignore_index=True)
#     # print(col)
#     # print(score)

# %%
# sd_0_impute = netflow_feats.merge(cat_ratio_feats, on = 'prism_consumer_id')

# sd_cols = [c for c in sd_0_impute.columns if c.startswith("sd_")]
# sd_0_impute[sd_cols] = sd_0_impute[sd_cols].fillna(0.0)

# y = med_impute['DQ_TARGET']

# # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~`
# # feature_cols = sd_0_impute.drop(
# #     columns=["prism_consumer_id", "DQ_TARGET", "evaluation_date"]
# # )

# temp_df = pd.DataFrame()
# for col in sd_cols:
#     X = sd_0_impute[[col]]
#     y = y
    
#     model = LogisticRegression(class_weight='balanced')
#     model.fit(X, y)
    
#     preds = model.predict_proba(X)[:, 1]
    
#     score = roc_auc_score(y, preds)

#     temp_df = pd.concat([temp_df, pd.DataFrame([{"feature": col, "auc_roc_sd_0": score}])],ignore_index=True)

# auc_df = auc_df.merge(temp_df, on='feature', how='left')
#     # print(col)
#     # print(score)
# auc_df

# %%
# auc_df['max_auc'] = np.where(auc_df['auc_roc_mean'] == auc_df['auc_roc_med'], 'same', 
#                             np.where(auc_df['auc_roc_mean'] > auc_df['auc_roc_med'], 'auc_roc_mean', 'auc_roc_med')
#                             )
# sd_rows = auc_df.index[auc_df["auc_roc_sd_0"].notna()].tolist()
# for r in sd_rows:
#     if auc_df.loc[r, 'max_auc'] == 'same':
#         if auc_df.loc[r, 'auc_roc_sd_0'] > auc_df.loc[r, 'auc_roc_mean']:
#             auc_df.loc[r, 'max_auc'] = 'auc_roc_sd_0'
#     else:
#         if auc_df.loc[r, 'auc_roc_sd_0'] > auc_df.loc[r, auc_df.loc[r, 'max_auc']]:
#             auc_df.loc[r, 'max_auc'] = 'auc_roc_sd_0'

# auc_df

# %%
from IPython.display import display

# Assume 'df' is your DataFrame

with pd.option_context('display.max_rows', None, 
                       'display.max_columns', None, 
                       'display.width', None,
                       'display.max_colwidth', None):
    display(auc_df.sort_values(by='auc_roc_mean', ascending=False))
# Out:
#                            feature  auc_roc_mean
# 0                  months_observed      0.660786
# 1                     total_income      0.594597
# 2                      total_spend      0.582362
# 3                   total_net_flow      0.522839
# 4                   avg_1m_netflow      0.518290
# 5                   med_1m_netflow      0.526434
# 6                    sd_1m_netflow      0.543766
# 7                   min_1m_netflow      0.529795
# 8                   max_1m_netflow      0.592898
# 9                   avg_3m_netflow      0.527424
# 10                  med_3m_netflow      0.529715
# 11                   sd_3m_netflow      0.530183
# 12                  min_3m_netflow      0.509105
# 13                  max_3m_netflow      0.580620
# 14                  avg_6m_netflow      0.609907
# 15                  med_6m_netflow      0.609052
# 16                   sd_6m_netflow      0.604159
# 17                  min_6m_netflow      0.613274
# 18                  max_6m_netflow      0.601175
# 19                  avg_9m_netflow      0.543210
# 20                  med_9m_netflow      0.543215
# 21                   sd_9m_netflow      0.504292
# 22                  min_9m_netflow      0.543022
# 23                  max_9m_netflow      0.543289
# 24               avg_cat0_spend_1m      0.583231
# 25               med_cat0_spend_1m      0.449724
# 26                sd_cat0_spend_1m      0.588767
# 27               min_cat0_spend_1m      0.510930
# 28               max_cat0_spend_1m      0.589929
# 29     avg_cat0_to_income_ratio_1m      0.424404
# 30     med_cat0_to_income_ratio_1m      0.451185
# 31      sd_cat0_to_income_ratio_1m      0.567532
# 32     min_cat0_to_income_ratio_1m      0.488546
# 33     max_cat0_to_income_ratio_1m      0.583594
# 34               avg_cat0_spend_3m      0.569267
# 99     avg_cat1_to_income_ratio_9m      0.438380
# 100    med_cat1_to_income_ratio_9m      0.438365
# 101     sd_cat1_to_income_ratio_9m      0.495277
# 102    min_cat1_to_income_ratio_9m      0.438446
# 103    max_cat1_to_income_ratio_9m      0.438456
# 104              avg_cat2_spend_1m      0.500000
# 105              med_cat2_spend_1m      0.500000
# 106               sd_cat2_spend_1m      0.500000
# 107              min_cat2_spend_1m      0.500000
# 108              max_cat2_spend_1m      0.500000
# 109    avg_cat2_to_income_ratio_1m      0.500000
# 110    med_cat2_to_income_ratio_1m      0.500000
# 111     sd_cat2_to_income_ratio_1m      0.500000
# 112    min_cat2_to_income_ratio_1m      0.500000
# 113    max_cat2_to_income_ratio_1m      0.500000
# 114              avg_cat2_spend_3m      0.500000
# 115              med_cat2_spend_3m      0.500000
# 116               sd_cat2_spend_3m      0.500000
# 117              min_cat2_spend_3m      0.500000
# 118              max_cat2_spend_3m      0.500000
# 119    avg_cat2_to_income_ratio_3m      0.500000
# 120    med_cat2_to_income_ratio_3m      0.500000
# 121     sd_cat2_to_income_ratio_3m      0.500000
# 122    min_cat2_to_income_ratio_3m      0.500000
# 123    max_cat2_to_income_ratio_3m      0.500000
# 124              avg_cat2_spend_6m      0.500000
# 125              med_cat2_spend_6m      0.500000
# 126               sd_cat2_spend_6m      0.500000
# 127              min_cat2_spend_6m      0.500000
# 128              max_cat2_spend_6m      0.500000
# 129    avg_cat2_to_income_ratio_6m      0.500000
# 130    med_cat2_to_income_ratio_6m      0.500000
# 131     sd_cat2_to_income_ratio_6m      0.500000
# 132    min_cat2_to_income_ratio_6m      0.500000
# 133    max_cat2_to_income_ratio_6m      0.500000
# 134              avg_cat2_spend_9m      0.500000
# 135              med_cat2_spend_9m      0.500000
# 136               sd_cat2_spend_9m      0.500000
# 137              min_cat2_spend_9m      0.500000
# 138              max_cat2_spend_9m      0.500000
# 139    avg_cat2_to_income_ratio_9m      0.500000
# 140    med_cat2_to_income_ratio_9m      0.500000
# 141     sd_cat2_to_income_ratio_9m      0.500000
# 142    min_cat2_to_income_ratio_9m      0.500000
# 143    max_cat2_to_income_ratio_9m      0.500000
# 144              avg_cat3_spend_1m      0.500000
# 145              med_cat3_spend_1m      0.500000
# 146               sd_cat3_spend_1m      0.500000
# 147              min_cat3_spend_1m      0.500000
# 148              max_cat3_spend_1m      0.500000
# 149    avg_cat3_to_income_ratio_1m      0.500000
# 150    med_cat3_to_income_ratio_1m      0.500000
# 151     sd_cat3_to_income_ratio_1m      0.500000
# 152    min_cat3_to_income_ratio_1m      0.500000
# 153    max_cat3_to_income_ratio_1m      0.500000
# 154              avg_cat3_spend_3m      0.500000
# 155              med_cat3_spend_3m      0.500000
# 156               sd_cat3_spend_3m      0.500000
# 157              min_cat3_spend_3m      0.500000
# 158              max_cat3_spend_3m      0.500000
# 159    avg_cat3_to_income_ratio_3m      0.500000
# 160    med_cat3_to_income_ratio_3m      0.500000
# 161     sd_cat3_to_income_ratio_3m      0.500000
# 162    min_cat3_to_income_ratio_3m      0.500000
# 163    max_cat3_to_income_ratio_3m      0.500000
# 164              avg_cat3_spend_6m      0.500000
# 165              med_cat3_spend_6m      0.500000
# 166               sd_cat3_spend_6m      0.500000
# 167              min_cat3_spend_6m      0.500000
# 168              max_cat3_spend_6m      0.500000
# 169    avg_cat3_to_income_ratio_6m      0.500000
# 170    med_cat3_to_income_ratio_6m      0.500000
# 171     sd_cat3_to_income_ratio_6m      0.500000
# 172    min_cat3_to_income_ratio_6m      0.500000
# 173    max_cat3_to_income_ratio_6m      0.500000
# 174              avg_cat3_spend_9m      0.500000
# 175              med_cat3_spend_9m      0.500000
# 176               sd_cat3_spend_9m      0.500000
# 177              min_cat3_spend_9m      0.500000
# 178              max_cat3_spend_9m      0.500000
# 179    avg_cat3_to_income_ratio_9m      0.500000
# 180    med_cat3_to_income_ratio_9m      0.500000
# 181     sd_cat3_to_income_ratio_9m      0.500000
# 182    min_cat3_to_income_ratio_9m      0.500000
# 183    max_cat3_to_income_ratio_9m      0.500000
# 184              avg_cat4_spend_1m      0.479651
# 185              med_cat4_spend_1m      0.475158
# 186               sd_cat4_spend_1m      0.490188
# 187              min_cat4_spend_1m      0.528888
# 188              max_cat4_spend_1m      0.496113
# 189    avg_cat4_to_income_ratio_1m      0.535396
# 190    med_cat4_to_income_ratio_1m      0.547030
# 191     sd_cat4_to_income_ratio_1m      0.525094
# 192    min_cat4_to_income_ratio_1m      0.546177
# 193    max_cat4_to_income_ratio_1m      0.514533
# 194              avg_cat4_spend_3m      0.477205
# 195              med_cat4_spend_3m      0.472211
# 196               sd_cat4_spend_3m      0.510078
# 197              min_cat4_spend_3m      0.560823
# 198              max_cat4_spend_3m      0.498410
# 199    avg_cat4_to_income_ratio_3m      0.545322
# 200    med_cat4_to_income_ratio_3m      0.554163
# 201     sd_cat4_to_income_ratio_3m      0.526294
# 202    min_cat4_to_income_ratio_3m      0.581888
# 203    max_cat4_to_income_ratio_3m      0.521705
# 204              avg_cat4_spend_6m      0.606350
# 205              med_cat4_spend_6m      0.605014
# 206               sd_cat4_spend_6m      0.609630
# 207              min_cat4_spend_6m      0.599219
# 208              max_cat4_spend_6m      0.610151
# 209    avg_cat4_to_income_ratio_6m      0.678568
# 210    med_cat4_to_income_ratio_6m      0.677490
# 211     sd_cat4_to_income_ratio_6m      0.658382
# 212    min_cat4_to_income_ratio_6m      0.676183
# 213    max_cat4_to_income_ratio_6m      0.680089
# 214              avg_cat4_spend_9m      0.460623
# 215              med_cat4_spend_9m      0.460617
# 216               sd_cat4_spend_9m      0.497502
# 217              min_cat4_spend_9m      0.460757
# 218              max_cat4_spend_9m      0.460572
# 219    avg_cat4_to_income_ratio_9m      0.441540
# 220    med_cat4_to_income_ratio_9m      0.441537
# 221     sd_cat4_to_income_ratio_9m      0.500000
# 222    min_cat4_to_income_ratio_9m      0.441496
# 223    max_cat4_to_income_ratio_9m      0.441570
# 224              avg_cat5_spend_1m      0.500000
# 225              med_cat5_spend_1m      0.500000
# 226               sd_cat5_spend_1m      0.500000
# 227              min_cat5_spend_1m      0.500000
# 228              max_cat5_spend_1m      0.500000
# 229    avg_cat5_to_income_ratio_1m      0.500000
# 230    med_cat5_to_income_ratio_1m      0.500000
# 231     sd_cat5_to_income_ratio_1m      0.500000
# 232    min_cat5_to_income_ratio_1m      0.500000
# 233    max_cat5_to_income_ratio_1m      0.500000
# 234              avg_cat5_spend_3m      0.500000
# 235              med_cat5_spend_3m      0.500000
# 236               sd_cat5_spend_3m      0.500000
# 237              min_cat5_spend_3m      0.500000
# 238              max_cat5_spend_3m      0.500000
# 239    avg_cat5_to_income_ratio_3m      0.500000
# 240    med_cat5_to_income_ratio_3m      0.500000
# 241     sd_cat5_to_income_ratio_3m      0.500000
# 242    min_cat5_to_income_ratio_3m      0.500000
# 243    max_cat5_to_income_ratio_3m      0.500000
# 244              avg_cat5_spend_6m      0.500000
# 245              med_cat5_spend_6m      0.500000
# 246               sd_cat5_spend_6m      0.500000
# 247              min_cat5_spend_6m      0.500000
# 248              max_cat5_spend_6m      0.500000
# 249    avg_cat5_to_income_ratio_6m      0.500000
# 250    med_cat5_to_income_ratio_6m      0.500000
# 251     sd_cat5_to_income_ratio_6m      0.500000
# 252    min_cat5_to_income_ratio_6m      0.500000
# 253    max_cat5_to_income_ratio_6m      0.500000
# 254              avg_cat5_spend_9m      0.500000
# 255              med_cat5_spend_9m      0.500000
# 256               sd_cat5_spend_9m      0.500000
# 257              min_cat5_spend_9m      0.500000
# 258              max_cat5_spend_9m      0.500000
# 259    avg_cat5_to_income_ratio_9m      0.500000
# 260    med_cat5_to_income_ratio_9m      0.500000
# 261     sd_cat5_to_income_ratio_9m      0.500000
# 262    min_cat5_to_income_ratio_9m      0.500000
# 263    max_cat5_to_income_ratio_9m      0.500000
# 264              avg_cat6_spend_1m      0.500000
# 265              med_cat6_spend_1m      0.500000
# 266               sd_cat6_spend_1m      0.500000
# 267              min_cat6_spend_1m      0.500000
# 268              max_cat6_spend_1m      0.500000
# 269    avg_cat6_to_income_ratio_1m      0.500000
# 270    med_cat6_to_income_ratio_1m      0.500000
# 271     sd_cat6_to_income_ratio_1m      0.500000
# 272    min_cat6_to_income_ratio_1m      0.500000
# 273    max_cat6_to_income_ratio_1m      0.500000
# 274              avg_cat6_spend_3m      0.500000
# 275              med_cat6_spend_3m      0.500000
# 276               sd_cat6_spend_3m      0.500000
# 277              min_cat6_spend_3m      0.500000
# 278              max_cat6_spend_3m      0.500000
# 279    avg_cat6_to_income_ratio_3m      0.500000
# 280    med_cat6_to_income_ratio_3m      0.500000
# 281     sd_cat6_to_income_ratio_3m      0.500000
# 282    min_cat6_to_income_ratio_3m      0.500000
# 283    max_cat6_to_income_ratio_3m      0.500000
# 284              avg_cat6_spend_6m      0.500000
# 285              med_cat6_spend_6m      0.500000
# 286               sd_cat6_spend_6m      0.500000
# 287              min_cat6_spend_6m      0.500000
# 288              max_cat6_spend_6m      0.500000
# 289    avg_cat6_to_income_ratio_6m      0.500000
# 290    med_cat6_to_income_ratio_6m      0.500000
# 291     sd_cat6_to_income_ratio_6m      0.500000
# 292    min_cat6_to_income_ratio_6m      0.500000
# 293    max_cat6_to_income_ratio_6m      0.500000
# 294              avg_cat6_spend_9m      0.500000
# 295              med_cat6_spend_9m      0.500000
# 296               sd_cat6_spend_9m      0.500000
# 297              min_cat6_spend_9m      0.500000
# 298              max_cat6_spend_9m      0.500000
# 299    avg_cat6_to_income_ratio_9m      0.500000
# 300    med_cat6_to_income_ratio_9m      0.500000
# 301     sd_cat6_to_income_ratio_9m      0.500000
# 302    min_cat6_to_income_ratio_9m      0.500000
# 303    max_cat6_to_income_ratio_9m      0.500000
# 304              avg_cat7_spend_1m      0.500000
# 305              med_cat7_spend_1m      0.500000
# 306               sd_cat7_spend_1m      0.500000
# 307              min_cat7_spend_1m      0.500000
# 308              max_cat7_spend_1m      0.500000
# 309    avg_cat7_to_income_ratio_1m      0.500000
# 310    med_cat7_to_income_ratio_1m      0.500000
# 311     sd_cat7_to_income_ratio_1m      0.500000
# 312    min_cat7_to_income_ratio_1m      0.500000
# 313    max_cat7_to_income_ratio_1m      0.500000
# 314              avg_cat7_spend_3m      0.500000
# 315              med_cat7_spend_3m      0.500000
# 316               sd_cat7_spend_3m      0.500000
# 317              min_cat7_spend_3m      0.500000
# 318              max_cat7_spend_3m      0.500000
# 319    avg_cat7_to_income_ratio_3m      0.500000
# 320    med_cat7_to_income_ratio_3m      0.500000
# 321     sd_cat7_to_income_ratio_3m      0.500000
# 322    min_cat7_to_income_ratio_3m      0.500000
# 323    max_cat7_to_income_ratio_3m      0.500000
# 324              avg_cat7_spend_6m      0.500000
# 325              med_cat7_spend_6m      0.500000
# 326               sd_cat7_spend_6m      0.500000
# 327              min_cat7_spend_6m      0.500000
# 328              max_cat7_spend_6m      0.500000
# 329    avg_cat7_to_income_ratio_6m      0.500000
# 330    med_cat7_to_income_ratio_6m      0.500000
# 331     sd_cat7_to_income_ratio_6m      0.500000
# 332    min_cat7_to_income_ratio_6m      0.500000
# 333    max_cat7_to_income_ratio_6m      0.500000
# 334              avg_cat7_spend_9m      0.500000
# 335              med_cat7_spend_9m      0.500000
# 336               sd_cat7_spend_9m      0.500000
# 337              min_cat7_spend_9m      0.500000
# 338              max_cat7_spend_9m      0.500000
# 339    avg_cat7_to_income_ratio_9m      0.500000
# 340    med_cat7_to_income_ratio_9m      0.500000
# 341     sd_cat7_to_income_ratio_9m      0.500000
# 342    min_cat7_to_income_ratio_9m      0.500000
# 343    max_cat7_to_income_ratio_9m      0.500000
# 344              avg_cat8_spend_1m      0.500000
# 345              med_cat8_spend_1m      0.500000
# 346               sd_cat8_spend_1m      0.500000
# 347              min_cat8_spend_1m      0.500000
# 348              max_cat8_spend_1m      0.500000
# 349    avg_cat8_to_income_ratio_1m      0.500000
# 350    med_cat8_to_income_ratio_1m      0.500000
# 351     sd_cat8_to_income_ratio_1m      0.500000
# 352    min_cat8_to_income_ratio_1m      0.500000
# 353    max_cat8_to_income_ratio_1m      0.500000
# 354              avg_cat8_spend_3m      0.500000
# 355              med_cat8_spend_3m      0.500000
# 356               sd_cat8_spend_3m      0.500000
# 357              min_cat8_spend_3m      0.500000
# 358              max_cat8_spend_3m      0.500000
# 359    avg_cat8_to_income_ratio_3m      0.500000
# 360    med_cat8_to_income_ratio_3m      0.500000
# 361     sd_cat8_to_income_ratio_3m      0.500000
# 362    min_cat8_to_income_ratio_3m      0.500000
# 363    max_cat8_to_income_ratio_3m      0.500000
# 364              avg_cat8_spend_6m      0.500000
# 365              med_cat8_spend_6m      0.500000
# 366               sd_cat8_spend_6m      0.500000
# 367              min_cat8_spend_6m      0.500000
# 368              max_cat8_spend_6m      0.500000
# 369    avg_cat8_to_income_ratio_6m      0.500000
# 370    med_cat8_to_income_ratio_6m      0.500000
# 371     sd_cat8_to_income_ratio_6m      0.500000
# 372    min_cat8_to_income_ratio_6m      0.500000
# 373    max_cat8_to_income_ratio_6m      0.500000
# 374              avg_cat8_spend_9m      0.500000
# 375              med_cat8_spend_9m      0.500000
# 376               sd_cat8_spend_9m      0.500000
# 377              min_cat8_spend_9m      0.500000
# 378              max_cat8_spend_9m      0.500000
# 379    avg_cat8_to_income_ratio_9m      0.500000
# 380    med_cat8_to_income_ratio_9m      0.500000
# 381     sd_cat8_to_income_ratio_9m      0.500000
# 382    min_cat8_to_income_ratio_9m      0.500000
# 383    max_cat8_to_income_ratio_9m      0.500000
# 384              avg_cat9_spend_1m      0.500000
# 385              med_cat9_spend_1m      0.500000
# 386               sd_cat9_spend_1m      0.500000
# 387              min_cat9_spend_1m      0.500000
# 388              max_cat9_spend_1m      0.500000
# 389    avg_cat9_to_income_ratio_1m      0.500000
# 390    med_cat9_to_income_ratio_1m      0.500000
# 391     sd_cat9_to_income_ratio_1m      0.500000
# 392    min_cat9_to_income_ratio_1m      0.500000
# 393    max_cat9_to_income_ratio_1m      0.500000
# 394              avg_cat9_spend_3m      0.500000
# 395              med_cat9_spend_3m      0.500000
# 396               sd_cat9_spend_3m      0.500000
# 397              min_cat9_spend_3m      0.500000
# 398              max_cat9_spend_3m      0.500000
# 399    avg_cat9_to_income_ratio_3m      0.500000
# 400    med_cat9_to_income_ratio_3m      0.500000
# 401     sd_cat9_to_income_ratio_3m      0.500000
# 402    min_cat9_to_income_ratio_3m      0.500000
# 403    max_cat9_to_income_ratio_3m      0.500000
# 404              avg_cat9_spend_6m      0.500000
# 405              med_cat9_spend_6m      0.500000
# 406               sd_cat9_spend_6m      0.500000
# 407              min_cat9_spend_6m      0.500000
# 408              max_cat9_spend_6m      0.500000
# 409    avg_cat9_to_income_ratio_6m      0.500000
# 410    med_cat9_to_income_ratio_6m      0.500000
# 411     sd_cat9_to_income_ratio_6m      0.500000
# 412    min_cat9_to_income_ratio_6m      0.500000
# 413    max_cat9_to_income_ratio_6m      0.500000
# 414              avg_cat9_spend_9m      0.500000
# 415              med_cat9_spend_9m      0.500000
# 416               sd_cat9_spend_9m      0.500000
# 417              min_cat9_spend_9m      0.500000
# 418              max_cat9_spend_9m      0.500000
# 419    avg_cat9_to_income_ratio_9m      0.500000
# 420    med_cat9_to_income_ratio_9m      0.500000
# 421     sd_cat9_to_income_ratio_9m      0.500000
# 422    min_cat9_to_income_ratio_9m      0.500000
# 423    max_cat9_to_income_ratio_9m      0.500000
# 424             avg_cat10_spend_1m      0.500000
# 425             med_cat10_spend_1m      0.500000
# 426              sd_cat10_spend_1m      0.500000
# 427             min_cat10_spend_1m      0.500000
# 428             max_cat10_spend_1m      0.500000
# 429   avg_cat10_to_income_ratio_1m      0.500000
# 430   med_cat10_to_income_ratio_1m      0.500000
# 431    sd_cat10_to_income_ratio_1m      0.500000
# 432   min_cat10_to_income_ratio_1m      0.500000
# 433   max_cat10_to_income_ratio_1m      0.500000
# 434             avg_cat10_spend_3m      0.500000
# 435             med_cat10_spend_3m      0.500000
# 436              sd_cat10_spend_3m      0.500000
# 437             min_cat10_spend_3m      0.500000
# 438             max_cat10_spend_3m      0.500000
# 439   avg_cat10_to_income_ratio_3m      0.500000
# 440   med_cat10_to_income_ratio_3m      0.500000
# 441    sd_cat10_to_income_ratio_3m      0.500000
# 442   min_cat10_to_income_ratio_3m      0.500000
# 443   max_cat10_to_income_ratio_3m      0.500000
# 444             avg_cat10_spend_6m      0.500000
# 445             med_cat10_spend_6m      0.500000
# 446              sd_cat10_spend_6m      0.500000
# 447             min_cat10_spend_6m      0.500000
# 448             max_cat10_spend_6m      0.500000
# 449   avg_cat10_to_income_ratio_6m      0.500000
# 450   med_cat10_to_income_ratio_6m      0.500000
# 451    sd_cat10_to_income_ratio_6m      0.500000
# 452   min_cat10_to_income_ratio_6m      0.500000
# 453   max_cat10_to_income_ratio_6m      0.500000
# 454             avg_cat10_spend_9m      0.500000
# 455             med_cat10_spend_9m      0.500000
# 456              sd_cat10_spend_9m      0.500000
# 457             min_cat10_spend_9m      0.500000
# 458             max_cat10_spend_9m      0.500000
# 459   avg_cat10_to_income_ratio_9m      0.500000
# 460   med_cat10_to_income_ratio_9m      0.500000
# 461    sd_cat10_to_income_ratio_9m      0.500000
# 462   min_cat10_to_income_ratio_9m      0.500000
# 463   max_cat10_to_income_ratio_9m      0.500000
# 464             avg_cat11_spend_1m      0.522206
# 465             med_cat11_spend_1m      0.499688
# 466              sd_cat11_spend_1m      0.527817
# 467             min_cat11_spend_1m      0.499878
# 468             max_cat11_spend_1m      0.522688
# 469   avg_cat11_to_income_ratio_1m      0.523303
# 470   med_cat11_to_income_ratio_1m      0.503532
# 471    sd_cat11_to_income_ratio_1m      0.513008
# 472   min_cat11_to_income_ratio_1m      0.504294
# 473   max_cat11_to_income_ratio_1m      0.523677
# 474             avg_cat11_spend_3m      0.513904
# 475             med_cat11_spend_3m      0.502890
# 476              sd_cat11_spend_3m      0.488775
# 477             min_cat11_spend_3m      0.488192
# 478             max_cat11_spend_3m      0.514392
# 479   avg_cat11_to_income_ratio_3m      0.512878
# 480   med_cat11_to_income_ratio_3m      0.502015
# 481    sd_cat11_to_income_ratio_3m      0.477010
# 482   min_cat11_to_income_ratio_3m      0.490190
# 612   min_cat14_to_income_ratio_6m      0.671046
# 613   max_cat14_to_income_ratio_6m      0.672000
# 614             avg_cat14_spend_9m      0.485110
# 615             med_cat14_spend_9m      0.485107
# 616              sd_cat14_spend_9m      0.497088
# 617             min_cat14_spend_9m      0.484262
# 618             max_cat14_spend_9m      0.484979
# 619   avg_cat14_to_income_ratio_9m      0.442027
# 620   med_cat14_to_income_ratio_9m      0.442028
# 621    sd_cat14_to_income_ratio_9m      0.500000
# 622   min_cat14_to_income_ratio_9m      0.441989
# 623   max_cat14_to_income_ratio_9m      0.442047
# 624             avg_cat15_spend_1m      0.500000
# 625             med_cat15_spend_1m      0.500000
# 626              sd_cat15_spend_1m      0.500000
# 627             min_cat15_spend_1m      0.500000
# 628             max_cat15_spend_1m      0.500000
# 629   avg_cat15_to_income_ratio_1m      0.500000
# 630   med_cat15_to_income_ratio_1m      0.500000
# 631    sd_cat15_to_income_ratio_1m      0.500000
# 632   min_cat15_to_income_ratio_1m      0.500000
# 633   max_cat15_to_income_ratio_1m      0.500000
# 634             avg_cat15_spend_3m      0.500000
# 635             med_cat15_spend_3m      0.500000
# 636              sd_cat15_spend_3m      0.500000
# 637             min_cat15_spend_3m      0.500000
# 638             max_cat15_spend_3m      0.500000
# 639   avg_cat15_to_income_ratio_3m      0.500000
# 640   med_cat15_to_income_ratio_3m      0.500000
# 641    sd_cat15_to_income_ratio_3m      0.500000
# 642   min_cat15_to_income_ratio_3m      0.500000
# 643   max_cat15_to_income_ratio_3m      0.500000
# 644             avg_cat15_spend_6m      0.500000
# 645             med_cat15_spend_6m      0.500000
# 646              sd_cat15_spend_6m      0.500000
# 647             min_cat15_spend_6m      0.500000
# 648             max_cat15_spend_6m      0.500000
# 649   avg_cat15_to_income_ratio_6m      0.500000
# 650   med_cat15_to_income_ratio_6m      0.500000
# 651    sd_cat15_to_income_ratio_6m      0.500000
# 652   min_cat15_to_income_ratio_6m      0.500000
# 653   max_cat15_to_income_ratio_6m      0.500000
# 654             avg_cat15_spend_9m      0.500000
# 655             med_cat15_spend_9m      0.500000
# 656              sd_cat15_spend_9m      0.500000
# 657             min_cat15_spend_9m      0.500000
# 658             max_cat15_spend_9m      0.500000
# 659   avg_cat15_to_income_ratio_9m      0.500000
# 660   med_cat15_to_income_ratio_9m      0.500000
# 661    sd_cat15_to_income_ratio_9m      0.500000
# 662   min_cat15_to_income_ratio_9m      0.500000
# 663   max_cat15_to_income_ratio_9m      0.500000
# 664             avg_cat16_spend_1m      0.512111
# 665             med_cat16_spend_1m      0.509018
# 666              sd_cat16_spend_1m      0.511613
# 667             min_cat16_spend_1m      0.507347
# 668             max_cat16_spend_1m      0.524087
# 669   avg_cat16_to_income_ratio_1m      0.502366
# 670   med_cat16_to_income_ratio_1m      0.511535
# 671    sd_cat16_to_income_ratio_1m      0.499324
# 672   min_cat16_to_income_ratio_1m      0.519082
# 673   max_cat16_to_income_ratio_1m      0.486480
# 674             avg_cat16_spend_3m      0.512062
# 675             med_cat16_spend_3m      0.509467
# 676              sd_cat16_spend_3m      0.532612
# 677             min_cat16_spend_3m      0.527151
# 678             max_cat16_spend_3m      0.531392
# 679   avg_cat16_to_income_ratio_3m      0.515190
# 680   med_cat16_to_income_ratio_3m      0.521037
# 681    sd_cat16_to_income_ratio_3m      0.511673
# 682   min_cat16_to_income_ratio_3m      0.546275
# 683   max_cat16_to_income_ratio_3m      0.496941
# 684             avg_cat16_spend_6m      0.567871
# 685             med_cat16_spend_6m      0.567919
# 686              sd_cat16_spend_6m      0.578495
# 687             min_cat16_spend_6m      0.563602
# 688             max_cat16_spend_6m      0.570511
# 689   avg_cat16_to_income_ratio_6m      0.671549
# 690   med_cat16_to_income_ratio_6m      0.671256
# 691    sd_cat16_to_income_ratio_6m      0.654434
# 692   min_cat16_to_income_ratio_6m      0.669369
# 693   max_cat16_to_income_ratio_6m      0.672655
# 694             avg_cat16_spend_9m      0.523269
# 695             med_cat16_spend_9m      0.523270
# 696              sd_cat16_spend_9m      0.502975
# 697             min_cat16_spend_9m      0.523029
# 698             max_cat16_spend_9m      0.523348
# 699   avg_cat16_to_income_ratio_9m      0.442719
# 700   med_cat16_to_income_ratio_9m      0.442720
# 701    sd_cat16_to_income_ratio_9m      0.495195
# 702   min_cat16_to_income_ratio_9m      0.442707
# 703   max_cat16_to_income_ratio_9m      0.442731
# 704             avg_cat17_spend_1m      0.540427
# 705             med_cat17_spend_1m      0.541133
# 706              sd_cat17_spend_1m      0.538976
# 707             min_cat17_spend_1m      0.540038
# 708             max_cat17_spend_1m      0.528196
# 709   avg_cat17_to_income_ratio_1m      0.558353
# 710   med_cat17_to_income_ratio_1m      0.564408
# 711    sd_cat17_to_income_ratio_1m      0.557920
# 712   min_cat17_to_income_ratio_1m      0.550939
# 713   max_cat17_to_income_ratio_1m      0.545782
# 714             avg_cat17_spend_3m      0.539489
# 715             med_cat17_spend_3m      0.542465
# 716              sd_cat17_spend_3m      0.512304
# 717             min_cat17_spend_3m      0.567984
# 718             max_cat17_spend_3m      0.520639
# 719   avg_cat17_to_income_ratio_3m      0.560689
# 720   med_cat17_to_income_ratio_3m      0.568308
# 721    sd_cat17_to_income_ratio_3m      0.540636
# 722   min_cat17_to_income_ratio_3m      0.589178
# 723   max_cat17_to_income_ratio_3m      0.542382
# 724             avg_cat17_spend_6m      0.577180
# 725             med_cat17_spend_6m      0.578862
# 726              sd_cat17_spend_6m      0.589073
# 727             min_cat17_spend_6m      0.571308
# 728             max_cat17_spend_6m      0.578740
# 729   avg_cat17_to_income_ratio_6m      0.676681
# 730   med_cat17_to_income_ratio_6m      0.676539
# 731    sd_cat17_to_income_ratio_6m      0.655061
# 732   min_cat17_to_income_ratio_6m      0.673880
# 733   max_cat17_to_income_ratio_6m      0.676823
# 734             avg_cat17_spend_9m      0.528923
# 735             med_cat17_spend_9m      0.528928
# 736              sd_cat17_spend_9m      0.494692
# 737             min_cat17_spend_9m      0.528953
# 738             max_cat17_spend_9m      0.528813
# 739   avg_cat17_to_income_ratio_9m      0.442354
# 1838            max_cat45_spend_3m      0.538018
# 1839  avg_cat45_to_income_ratio_3m      0.532881
# 1840  med_cat45_to_income_ratio_3m      0.520255
# 1841   sd_cat45_to_income_ratio_3m      0.494824
# 1842  min_cat45_to_income_ratio_3m      0.505155
# 1843  max_cat45_to_income_ratio_3m      0.533732
# 1844            avg_cat45_spend_6m      0.369187
# 1845            med_cat45_spend_6m      0.370320
# 1846             sd_cat45_spend_6m      0.384143
# 1847            min_cat45_spend_6m      0.368336
# 1848            max_cat45_spend_6m      0.369824
# 1849  avg_cat45_to_income_ratio_6m      0.333277
# 1850  med_cat45_to_income_ratio_6m      0.333629
# 1851   sd_cat45_to_income_ratio_6m      0.644399
# 1852  min_cat45_to_income_ratio_6m      0.334774
# 1853  max_cat45_to_income_ratio_6m      0.333375
# 1854            avg_cat45_spend_9m      0.464183
# 1855            med_cat45_spend_9m      0.464177
# 1856             sd_cat45_spend_9m      0.495511
# 1857            min_cat45_spend_9m      0.464171
# 1858            max_cat45_spend_9m      0.464185
# 1859  avg_cat45_to_income_ratio_9m      0.457803
# 1860  med_cat45_to_income_ratio_9m      0.457795
# 1861   sd_cat45_to_income_ratio_9m      0.500000
# 1862  min_cat45_to_income_ratio_9m      0.457866
# 1863  max_cat45_to_income_ratio_9m      0.457806
# 1864            avg_cat46_spend_1m      0.509454
# 1865            med_cat46_spend_1m      0.505341
# 1866             sd_cat46_spend_1m      0.503486
# 1867            min_cat46_spend_1m      0.503527
# 1868            max_cat46_spend_1m      0.509037
# 1869  avg_cat46_to_income_ratio_1m      0.503440
# 1870  med_cat46_to_income_ratio_1m      0.503301
# 1871   sd_cat46_to_income_ratio_1m      0.510783
# 1872  min_cat46_to_income_ratio_1m      0.503050
# 1873  max_cat46_to_income_ratio_1m      0.503132
# 1874            avg_cat46_spend_3m      0.517937
# 1875            med_cat46_spend_3m      0.524635
# 1876             sd_cat46_spend_3m      0.537719
# 1877            min_cat46_spend_3m      0.523018
# 1878            max_cat46_spend_3m      0.517170
# 1879  avg_cat46_to_income_ratio_3m      0.515614
# 1880  med_cat46_to_income_ratio_3m      0.522405
# 1881   sd_cat46_to_income_ratio_3m      0.545572
# 1882  min_cat46_to_income_ratio_3m      0.478428
# 1883  max_cat46_to_income_ratio_3m      0.514986
# 1884            avg_cat46_spend_6m      0.667944
# 1885            med_cat46_spend_6m      0.667424
# 1886             sd_cat46_spend_6m      0.646092
# 1887            min_cat46_spend_6m      0.667080
# 1888            max_cat46_spend_6m      0.667453
# 1889  avg_cat46_to_income_ratio_6m      0.671789
# 1890  med_cat46_to_income_ratio_6m      0.665569
# 1891   sd_cat46_to_income_ratio_6m      0.654091
# 1892  min_cat46_to_income_ratio_6m      0.662275
# 1893  max_cat46_to_income_ratio_6m      0.675215
# 1894            avg_cat46_spend_9m      0.559810
# 1895            med_cat46_spend_9m      0.559824
# 1896             sd_cat46_spend_9m      0.505996
# 1897            min_cat46_spend_9m      0.559902
# 1898            max_cat46_spend_9m      0.559730
# 1899  avg_cat46_to_income_ratio_9m      0.561293
# 1900  med_cat46_to_income_ratio_9m      0.561309
# 1901   sd_cat46_to_income_ratio_9m      0.500000
# 1902  min_cat46_to_income_ratio_9m      0.561387
# 1903  max_cat46_to_income_ratio_9m      0.561214
# 1904            avg_cat47_spend_1m      0.501267
# 1905            med_cat47_spend_1m      0.500851
# 1906             sd_cat47_spend_1m      0.506783
# 1907            min_cat47_spend_1m      0.500142
# 1908            max_cat47_spend_1m      0.501267
# 1909  avg_cat47_to_income_ratio_1m      0.504475
# 1910  med_cat47_to_income_ratio_1m      0.504124
# 1911   sd_cat47_to_income_ratio_1m      0.496226
# 1912  min_cat47_to_income_ratio_1m      0.500000
# 1913  max_cat47_to_income_ratio_1m      0.504476
# 1914            avg_cat47_spend_3m      0.492563
# 1915            med_cat47_spend_3m      0.491939
# 1916             sd_cat47_spend_3m      0.540812
# 1917            min_cat47_spend_3m      0.492205
# 1918            max_cat47_spend_3m      0.492563
# 1919  avg_cat47_to_income_ratio_3m      0.494513
# 1920  med_cat47_to_income_ratio_3m      0.493938
# 1921   sd_cat47_to_income_ratio_3m      0.462031
# 1922  min_cat47_to_income_ratio_3m      0.494190
# 1923  max_cat47_to_income_ratio_3m      0.494505
# 1924            avg_cat47_spend_6m      0.326982
# 1925            med_cat47_spend_6m      0.326738
# 1926             sd_cat47_spend_6m      0.349533
# 1927            min_cat47_spend_6m      0.326211
# 1928            max_cat47_spend_6m      0.326982
# 1929  avg_cat47_to_income_ratio_6m      0.500000
# 1930  med_cat47_to_income_ratio_6m      0.500000
# 1931   sd_cat47_to_income_ratio_6m      0.500000
# 1932  min_cat47_to_income_ratio_6m      0.500000
# 1933  max_cat47_to_income_ratio_6m      0.500000
# 1934            avg_cat47_spend_9m      0.442572
# 1935            med_cat47_spend_9m      0.442572
# 1936             sd_cat47_spend_9m      0.500000
# 1937            min_cat47_spend_9m      0.442572
# 1938            max_cat47_spend_9m      0.442572
# 1939  avg_cat47_to_income_ratio_9m      0.500000
# 1940  med_cat47_to_income_ratio_9m      0.500000
# 1941   sd_cat47_to_income_ratio_9m      0.500000
# 1942  min_cat47_to_income_ratio_9m      0.500000
# 1943  max_cat47_to_income_ratio_9m      0.500000
# 1944            avg_cat48_spend_1m      0.500000
# 1945            med_cat48_spend_1m      0.500000
# 1946             sd_cat48_spend_1m      0.500000
# 1947            min_cat48_spend_1m      0.500000
# 1948            max_cat48_spend_1m      0.500000
# 1949  avg_cat48_to_income_ratio_1m      0.500000
# 1950  med_cat48_to_income_ratio_1m      0.500000
# 1951   sd_cat48_to_income_ratio_1m      0.500000
# 1952  min_cat48_to_income_ratio_1m      0.500000
# 1953  max_cat48_to_income_ratio_1m      0.500000
# 1954            avg_cat48_spend_3m      0.500000
# 1955            med_cat48_spend_3m      0.500000
# 1956             sd_cat48_spend_3m      0.500000
# 1957            min_cat48_spend_3m      0.500000
# 1958            max_cat48_spend_3m      0.500000
# 1959  avg_cat48_to_income_ratio_3m      0.500000
# 1960  med_cat48_to_income_ratio_3m      0.500000
# 2022  min_cat49_to_income_ratio_9m      0.500000
# 2023  max_cat49_to_income_ratio_9m      0.500000

# %%
from IPython.display import display

# Assume 'df' is your DataFrame

with pd.option_context('display.max_rows', None, 
                       'display.max_columns', None, 
                       'display.width', None,
                       'display.max_colwidth', None):
    display(auc_df.sort_values(by='auc_roc_mean', ascending=False))
# Out:
#                            feature  auc_roc_mean
# 970   med_cat23_to_income_ratio_6m      0.688311
# 973   max_cat23_to_income_ratio_6m      0.688053
# 969   avg_cat23_to_income_ratio_6m      0.687923
# 533   max_cat12_to_income_ratio_6m      0.687762
# 529   avg_cat12_to_income_ratio_6m      0.687587
# 530   med_cat12_to_income_ratio_6m      0.685975
# 972   min_cat23_to_income_ratio_6m      0.685498
# 813   max_cat19_to_income_ratio_6m      0.685386
# 1093  max_cat26_to_income_ratio_6m      0.684781
# 532   min_cat12_to_income_ratio_6m      0.684715
# 809   avg_cat19_to_income_ratio_6m      0.684443
# 1090  med_cat26_to_income_ratio_6m      0.684384
# 1089  avg_cat26_to_income_ratio_6m      0.684228
# 810   med_cat19_to_income_ratio_6m      0.683131
# 1049  avg_cat25_to_income_ratio_6m      0.683074
# 1449  avg_cat35_to_income_ratio_6m      0.682999
# 1453  max_cat35_to_income_ratio_6m      0.682916
# 1092  min_cat26_to_income_ratio_6m      0.682725
# 1053  max_cat25_to_income_ratio_6m      0.682722
# 1050  med_cat25_to_income_ratio_6m      0.682140
# 1450  med_cat35_to_income_ratio_6m      0.682039
# 812   min_cat19_to_income_ratio_6m      0.681820
# 933   max_cat22_to_income_ratio_6m      0.681216
# 929   avg_cat22_to_income_ratio_6m      0.680429
# 213    max_cat4_to_income_ratio_6m      0.680089
# 1452  min_cat35_to_income_ratio_6m      0.680004
# 93     max_cat1_to_income_ratio_6m      0.679948
# 930   med_cat22_to_income_ratio_6m      0.679380
# 89     avg_cat1_to_income_ratio_6m      0.678779
# 209    avg_cat4_to_income_ratio_6m      0.678568
# 92     min_cat1_to_income_ratio_6m      0.678254
# 90     med_cat1_to_income_ratio_6m      0.677931
# 210    med_cat4_to_income_ratio_6m      0.677490
# 1052  min_cat25_to_income_ratio_6m      0.677475
# 733   max_cat17_to_income_ratio_6m      0.676823
# 729   avg_cat17_to_income_ratio_6m      0.676681
# 730   med_cat17_to_income_ratio_6m      0.676539
# 212    min_cat4_to_income_ratio_6m      0.676183
# 1293  max_cat31_to_income_ratio_6m      0.675719
# 573   max_cat13_to_income_ratio_6m      0.675368
# 1290  med_cat31_to_income_ratio_6m      0.675322
# 1893  max_cat46_to_income_ratio_6m      0.675215
# 893   max_cat21_to_income_ratio_6m      0.675068
# 1289  avg_cat31_to_income_ratio_6m      0.674944
# 1653  max_cat40_to_income_ratio_6m      0.674829
# 569   avg_cat13_to_income_ratio_6m      0.674577
# 889   avg_cat21_to_income_ratio_6m      0.674525
# 570   med_cat13_to_income_ratio_6m      0.674053
# 732   min_cat17_to_income_ratio_6m      0.673880
# 890   med_cat21_to_income_ratio_6m      0.673760
# 1649  avg_cat40_to_income_ratio_6m      0.673324
# 1364            avg_cat33_spend_6m      0.662755
# 1172  min_cat28_to_income_ratio_6m      0.662585
# 971    sd_cat23_to_income_ratio_6m      0.662429
# 1892  min_cat46_to_income_ratio_6m      0.662275
# 1368            max_cat33_spend_6m      0.662148
# 1045            med_cat25_spend_6m      0.661801
# 811    sd_cat19_to_income_ratio_6m      0.661710
# 1091   sd_cat26_to_income_ratio_6m      0.661628
# 0                  months_observed      0.660786
# 1451   sd_cat35_to_income_ratio_6m      0.660078
# 53     max_cat0_to_income_ratio_6m      0.659837
# 49     avg_cat0_to_income_ratio_6m      0.659319
# 50     med_cat0_to_income_ratio_6m      0.659059
# 931    sd_cat22_to_income_ratio_6m      0.658950
# 1051   sd_cat25_to_income_ratio_6m      0.658755
# 1047            min_cat25_spend_6m      0.658633
# 52     min_cat0_to_income_ratio_6m      0.658593
# 211     sd_cat4_to_income_ratio_6m      0.658382
# 91      sd_cat1_to_income_ratio_6m      0.655503
# 731    sd_cat17_to_income_ratio_6m      0.655061
# 1651   sd_cat40_to_income_ratio_6m      0.654439
# 691    sd_cat16_to_income_ratio_6m      0.654434
# 1891   sd_cat46_to_income_ratio_6m      0.654091
# 1613  max_cat39_to_income_ratio_6m      0.653911
# 611    sd_cat14_to_income_ratio_6m      0.653821
# 571    sd_cat13_to_income_ratio_6m      0.653192
# 891    sd_cat21_to_income_ratio_6m      0.652352
# 1531   sd_cat37_to_income_ratio_6m      0.651458
# 1011   sd_cat24_to_income_ratio_6m      0.650008
# 1131   sd_cat27_to_income_ratio_6m      0.650005
# 488             max_cat11_spend_6m      0.649711
# 1731   sd_cat42_to_income_ratio_6m      0.649635
# 771    sd_cat18_to_income_ratio_6m      0.649413
# 851    sd_cat20_to_income_ratio_6m      0.649359
# 1252  min_cat30_to_income_ratio_6m      0.649302
# 1487            min_cat36_spend_6m      0.649062
# 1806             sd_cat44_spend_6m      0.648286
# 1528            max_cat37_spend_6m      0.646486
# 1886             sd_cat46_spend_6m      0.646092
# 1251   sd_cat30_to_income_ratio_6m      0.645943
# 1444            avg_cat35_spend_6m      0.645398
# 1485            med_cat36_spend_6m      0.644897
# 1484            avg_cat36_spend_6m      0.644470
# 1445            med_cat35_spend_6m      0.644456
# 1851   sd_cat45_to_income_ratio_6m      0.644399
# 1686             sd_cat41_spend_6m      0.644399
# 1447            min_cat35_spend_6m      0.644186
# 1366             sd_cat33_spend_6m      0.643714
# 1448            max_cat35_spend_6m      0.642899
# 1247            min_cat30_spend_6m      0.641855
# 1488            max_cat36_spend_6m      0.641763
# 967             min_cat23_spend_6m      0.641653
# 51      sd_cat0_to_income_ratio_6m      0.641276
# 964             avg_cat23_spend_6m      0.639356
# 968             max_cat23_spend_6m      0.639010
# 965             med_cat23_spend_6m      0.638760
# 1245            med_cat30_spend_6m      0.638277
# 1244            avg_cat30_spend_6m      0.637969
# 1046             sd_cat25_spend_6m      0.636665
# 486              sd_cat11_spend_6m      0.635767
# 1248            max_cat30_spend_6m      0.635708
# 808             max_cat19_spend_6m      0.625482
# 806              sd_cat19_spend_6m      0.624845
# 1486             sd_cat36_spend_6m      0.624631
# 805             med_cat19_spend_6m      0.624178
# 1446             sd_cat35_spend_6m      0.623995
# 804             avg_cat19_spend_6m      0.623735
# 1246             sd_cat30_spend_6m      0.623712
# 957             min_cat23_spend_3m      0.622924
# 966              sd_cat23_spend_6m      0.622606
# 525             med_cat12_spend_6m      0.622583
# 528             max_cat12_spend_6m      0.622552
# 807             min_cat19_spend_6m      0.622510
# 524             avg_cat12_spend_6m      0.622290
# 1004            avg_cat24_spend_6m      0.621752
# 1008            max_cat24_spend_6m      0.621331
# 1005            med_cat24_spend_6m      0.621233
# 527             min_cat12_spend_6m      0.621141
# 1007            min_cat24_spend_6m      0.619689
# 962   min_cat23_to_income_ratio_3m      0.618632
# 82     min_cat1_to_income_ratio_3m      0.617410
# 802   min_cat19_to_income_ratio_3m      0.617000
# 526              sd_cat12_spend_6m      0.614633
# 86                sd_cat1_spend_6m      0.614256
# 797             min_cat19_spend_3m      0.613770
# 955             med_cat23_spend_3m      0.613544
# 17                  min_6m_netflow      0.613274
# 960   med_cat23_to_income_ratio_3m      0.612821
# 84               avg_cat1_spend_6m      0.612639
# 85               med_cat1_spend_6m      0.612638
# 88               max_cat1_spend_6m      0.612414
# 1406             sd_cat34_spend_6m      0.611441
# 887             min_cat21_spend_6m      0.610615
# 208              max_cat4_spend_6m      0.610151
# 14                  avg_6m_netflow      0.609907
# 206               sd_cat4_spend_6m      0.609630
# 15                  med_6m_netflow      0.609052
# 885             med_cat21_spend_6m      0.608065
# 1006             sd_cat24_spend_6m      0.608049
# 888             max_cat21_spend_6m      0.607425
# 884             avg_cat21_spend_6m      0.606810
# 204              avg_cat4_spend_6m      0.606350
# 954             avg_cat23_spend_3m      0.606159
# 205              med_cat4_spend_6m      0.605014
# 1646             sd_cat40_spend_6m      0.604855
# 959   avg_cat23_to_income_ratio_3m      0.604235
# 16                   sd_6m_netflow      0.604159
# 961    sd_cat23_to_income_ratio_3m      0.604112
# 1086             sd_cat26_spend_6m      0.602382
# 886              sd_cat21_spend_6m      0.602307
# 18                  max_6m_netflow      0.601175
# 1648            max_cat40_spend_6m      0.600334
# 944             avg_cat23_spend_1m      0.599888
# 1645            med_cat40_spend_6m      0.599472
# 207              min_cat4_spend_6m      0.599219
# 800   med_cat19_to_income_ratio_3m      0.598337
# 1644            avg_cat40_spend_6m      0.598314
# 1647            min_cat40_spend_6m      0.597892
# 963   max_cat23_to_income_ratio_3m      0.597171
# 1126             sd_cat27_spend_6m      0.596158
# 958             max_cat23_spend_3m      0.595738
# 1285            med_cat31_spend_6m      0.595640
# 1284            avg_cat31_spend_6m      0.595622
# 945             med_cat23_spend_1m      0.595301
# 1288            max_cat31_spend_6m      0.595148
# 1                     total_income      0.594597
# 1286             sd_cat31_spend_6m      0.593757
# 8                   max_1m_netflow      0.592898
# 77               min_cat1_spend_3m      0.592432
# 949   avg_cat23_to_income_ratio_1m      0.591675
# 46                sd_cat0_spend_6m      0.591560
# 795             med_cat19_spend_3m      0.591060
# 72     min_cat1_to_income_ratio_1m      0.590510
# 28               max_cat0_spend_1m      0.589929
# 70     med_cat1_to_income_ratio_1m      0.589794
# 722   min_cat17_to_income_ratio_3m      0.589178
# 726              sd_cat17_spend_6m      0.589073
# 26                sd_cat0_spend_1m      0.588767
# 1041   sd_cat25_to_income_ratio_3m      0.588699
# 950   med_cat23_to_income_ratio_1m      0.588675
# 80     med_cat1_to_income_ratio_3m      0.587826
# 948             max_cat23_spend_1m      0.587101
# 790   med_cat19_to_income_ratio_1m      0.586994
# 1127            min_cat27_spend_6m      0.586725
# 1128            max_cat27_spend_6m      0.585605
# 799   avg_cat19_to_income_ratio_3m      0.584889
# 1125            med_cat27_spend_6m      0.584457
# 785             med_cat19_spend_1m      0.584108
# 953   max_cat23_to_income_ratio_1m      0.584094
# 1124            avg_cat27_spend_6m      0.583904
# 33     max_cat0_to_income_ratio_1m      0.583594
# 24               avg_cat0_spend_1m      0.583231
# 951    sd_cat23_to_income_ratio_1m      0.583022
# 2                      total_spend      0.582362
# 202    min_cat4_to_income_ratio_3m      0.581888
# 946              sd_cat23_spend_1m      0.581132
# 924             avg_cat22_spend_6m      0.580934
# 925             med_cat22_spend_6m      0.580763
# 13                  max_3m_netflow      0.580620
# 928             max_cat22_spend_6m      0.580352
# 927             min_cat22_spend_6m      0.579454
# 789   avg_cat19_to_income_ratio_1m      0.579028
# 725             med_cat17_spend_6m      0.578862
# 784             avg_cat19_spend_1m      0.578856
# 728             max_cat17_spend_6m      0.578740
# 686              sd_cat16_spend_6m      0.578495
# 568             max_cat13_spend_6m      0.578045
# 564             avg_cat13_spend_6m      0.577976
# 794             avg_cat19_spend_3m      0.577579
# 724             avg_cat17_spend_6m      0.577180
# 565             med_cat13_spend_6m      0.576890
# 38               max_cat0_spend_3m      0.576847
# 1034            avg_cat25_spend_3m      0.576723
# 1035            med_cat25_spend_3m      0.576417
# 567             min_cat13_spend_6m      0.576053
# 1441   sd_cat35_to_income_ratio_3m      0.575906
# 79     avg_cat1_to_income_ratio_3m      0.575729
# 926              sd_cat22_spend_6m      0.574007
# 1038            max_cat25_spend_3m      0.573463
# 801    sd_cat19_to_income_ratio_3m      0.573212
# 566              sd_cat13_spend_6m      0.573000
# 606              sd_cat14_spend_6m      0.572323
# 956              sd_cat23_spend_3m      0.572105
# 727             min_cat17_spend_6m      0.571308
# 1037            min_cat25_spend_3m      0.571172
# 688             max_cat16_spend_6m      0.570511
# 1039  avg_cat25_to_income_ratio_3m      0.569988
# 766              sd_cat18_spend_6m      0.569978
# 1040  med_cat25_to_income_ratio_3m      0.569570
# 34               avg_cat0_spend_3m      0.569267
# 1036             sd_cat25_spend_3m      0.569097
# 1024            avg_cat25_spend_1m      0.569095
# 803   max_cat19_to_income_ratio_3m      0.568834
# 791    sd_cat19_to_income_ratio_1m      0.568648
# 720   med_cat17_to_income_ratio_3m      0.568308
# 1043  max_cat25_to_income_ratio_3m      0.568260
# 717             min_cat17_spend_3m      0.567984
# 473   max_cat11_to_income_ratio_1m      0.523677
# 1835            med_cat45_spend_3m      0.523577
# 586              sd_cat14_spend_1m      0.523576
# 698             max_cat16_spend_9m      0.523348
# 469   avg_cat11_to_income_ratio_1m      0.523303
# 695             med_cat16_spend_9m      0.523270
# 694             avg_cat16_spend_9m      0.523269
# 1194            avg_cat29_spend_3m      0.523204
# 747             min_cat18_spend_1m      0.523050
# 697             min_cat16_spend_9m      0.523029
# 1877            min_cat46_spend_3m      0.523018
# 1313  max_cat32_to_income_ratio_1m      0.522920
# 1635            med_cat40_spend_3m      0.522888
# 1159  avg_cat28_to_income_ratio_3m      0.522859
# 3                   total_net_flow      0.522839
# 1309  avg_cat32_to_income_ratio_1m      0.522774
# 468             max_cat11_spend_1m      0.522688
# 1880  med_cat46_to_income_ratio_3m      0.522405
# 548             max_cat13_spend_1m      0.522396
# 947             min_cat23_spend_1m      0.522383
# 546              sd_cat13_spend_1m      0.522369
# 464             avg_cat11_spend_1m      0.522206
# 1203  max_cat29_to_income_ratio_3m      0.522169
# 1228            max_cat30_spend_1m      0.522162
# 1427            min_cat35_spend_1m      0.522144
# 1513  max_cat37_to_income_ratio_1m      0.521867
# 556              sd_cat13_spend_3m      0.521837
# 1464            avg_cat36_spend_1m      0.521734
# 203    max_cat4_to_income_ratio_3m      0.521705
# 996              sd_cat24_spend_3m      0.521680
# 1224            avg_cat30_spend_1m      0.521607
# 554             avg_cat13_spend_3m      0.521575
# 1506             sd_cat37_spend_1m      0.521472
# 1785            med_cat44_spend_1m      0.521424
# 840   med_cat20_to_income_ratio_3m      0.521384
# 880   med_cat21_to_income_ratio_3m      0.521275
# 1625            med_cat40_spend_1m      0.521248
# 1199  avg_cat29_to_income_ratio_3m      0.521072
# 680   med_cat16_to_income_ratio_3m      0.521037
# 1067            min_cat26_spend_1m      0.520991
# 1304            avg_cat32_spend_1m      0.520660
# 718             max_cat17_spend_3m      0.520639
# 1308            max_cat32_spend_1m      0.520507
# 777             min_cat18_spend_9m      0.520354
# 1509  avg_cat37_to_income_ratio_1m      0.520293
# 1840  med_cat45_to_income_ratio_3m      0.520255
# 1282  min_cat31_to_income_ratio_3m      0.520075
# 778             max_cat18_spend_9m      0.520031
# 603   max_cat14_to_income_ratio_3m      0.519625
# 775             med_cat18_spend_9m      0.519448
# 1825            med_cat45_spend_1m      0.519448
# 774             avg_cat18_spend_9m      0.519439
# 875             med_cat21_spend_3m      0.519314
# 905             med_cat22_spend_1m      0.519228
# 672   min_cat16_to_income_ratio_1m      0.519082
# 1081   sd_cat26_to_income_ratio_3m      0.518973
# 1469  avg_cat36_to_income_ratio_1m      0.518569
# 1473  max_cat36_to_income_ratio_1m      0.518536
# 1076             sd_cat26_spend_3m      0.518441
# 1508            max_cat37_spend_1m      0.518393
# 1077            min_cat26_spend_3m      0.518356
# 4                   avg_1m_netflow      0.518290
# 1639  avg_cat40_to_income_ratio_3m      0.518038
# 1874            avg_cat46_spend_3m      0.517937
# 1115            med_cat27_spend_3m      0.517850
# 1790  med_cat44_to_income_ratio_1m      0.517609
# 552   min_cat13_to_income_ratio_1m      0.517600
# 1001   sd_cat24_to_income_ratio_3m      0.517501
# 1878            max_cat46_spend_3m      0.517170
# 833   max_cat20_to_income_ratio_1m      0.517156
# 1389  avg_cat34_to_income_ratio_1m      0.517003
# 1717            min_cat42_spend_3m      0.516927
# 1393  max_cat34_to_income_ratio_1m      0.516919
# 1273  max_cat31_to_income_ratio_1m      0.516426
# 1504            avg_cat37_spend_1m      0.516405
# 1879  avg_cat46_to_income_ratio_3m      0.515614
# 1630  med_cat40_to_income_ratio_1m      0.515557
# 1000  med_cat24_to_income_ratio_3m      0.515537
# 1586             sd_cat39_spend_1m      0.515436
# 587             min_cat14_spend_1m      0.515313
# 679   avg_cat16_to_income_ratio_3m      0.515190
# 1883  max_cat46_to_income_ratio_3m      0.514986
# 1593  max_cat39_to_income_ratio_1m      0.514591
# 1266             sd_cat31_spend_1m      0.514558
# 1390  med_cat34_to_income_ratio_1m      0.514546
# 193    max_cat4_to_income_ratio_1m      0.514533
# 1268            max_cat31_spend_1m      0.514526
# 555             med_cat13_spend_3m      0.514427
# 1238            max_cat30_spend_3m      0.514398
# 478             max_cat11_spend_3m      0.514392
# 824             avg_cat20_spend_1m      0.514323
# 1628            max_cat40_spend_1m      0.514304
# 1318            max_cat32_spend_3m      0.514287
# 1357            min_cat33_spend_3m      0.514224
# 1264            avg_cat31_spend_1m      0.514068
# 474             avg_cat11_spend_3m      0.513904
# 1626             sd_cat40_spend_1m      0.513894
# 1314            avg_cat32_spend_3m      0.513760
# 1269  avg_cat31_to_income_ratio_1m      0.513719
# 1155            med_cat28_spend_3m      0.513694
# 1589  avg_cat39_to_income_ratio_1m      0.513560
# 563   max_cat13_to_income_ratio_3m      0.513438
# 1666             sd_cat41_spend_1m      0.513263
# 483   max_cat11_to_income_ratio_3m      0.513009
# 471    sd_cat11_to_income_ratio_1m      0.513008
# 1384            avg_cat34_spend_1m      0.512939
# 479   avg_cat11_to_income_ratio_3m      0.512878
# 1234            avg_cat30_spend_3m      0.512807
# 1355            med_cat33_spend_3m      0.512722
# 1720  med_cat42_to_income_ratio_3m      0.512712
# 1280  med_cat31_to_income_ratio_3m      0.512434
# 1311   sd_cat32_to_income_ratio_1m      0.512413
# 865             med_cat21_spend_1m      0.512411
# 716              sd_cat17_spend_3m      0.512304
# 1278            max_cat31_spend_3m      0.512278
# 1388            max_cat34_spend_1m      0.512273
# 1265            med_cat31_spend_1m      0.512259
# 1636             sd_cat40_spend_3m      0.512230
# 1150  med_cat28_to_income_ratio_1m      0.512162
# 664             avg_cat16_spend_1m      0.512111
# 674             avg_cat16_spend_3m      0.512062
# 1323  max_cat32_to_income_ratio_3m      0.512039
# 1277            min_cat31_spend_3m      0.512030
# 1588            max_cat39_spend_1m      0.511953
# 907             min_cat22_spend_1m      0.511896
# 1319  avg_cat32_to_income_ratio_3m      0.511798
# 1385            med_cat34_spend_1m      0.511774
# 1362  min_cat33_to_income_ratio_3m      0.511750
# 1310  med_cat32_to_income_ratio_1m      0.511713
# 681    sd_cat16_to_income_ratio_3m      0.511673
# 1156             sd_cat28_spend_3m      0.511670
# 666              sd_cat16_spend_1m      0.511613
# 670   med_cat16_to_income_ratio_1m      0.511535
# 1465            med_cat36_spend_1m      0.511485
# 912   min_cat22_to_income_ratio_1m      0.511382
# 1360  med_cat33_to_income_ratio_3m      0.511155
# 1242  min_cat30_to_income_ratio_3m      0.510977
# 27               min_cat0_spend_1m      0.510930
# 1871   sd_cat46_to_income_ratio_1m      0.510783
# 1190  med_cat29_to_income_ratio_1m      0.510741
# 1832  min_cat45_to_income_ratio_1m      0.510648
# 1584            avg_cat39_spend_1m      0.510582
# 870   med_cat21_to_income_ratio_1m      0.510468
# 1673  max_cat41_to_income_ratio_1m      0.510420
# 1669  avg_cat41_to_income_ratio_1m      0.510371
# 196               sd_cat4_spend_3m      0.510078
# 1632  min_cat40_to_income_ratio_1m      0.509905
# 832   min_cat20_to_income_ratio_1m      0.509821
# 872   min_cat21_to_income_ratio_1m      0.509533
# 1027            min_cat25_spend_1m      0.509487
# 675             med_cat16_spend_3m      0.509467
# 1864            avg_cat46_spend_1m      0.509454
# 1105            med_cat27_spend_1m      0.509394
# 834             avg_cat20_spend_3m      0.509390
# 1511   sd_cat37_to_income_ratio_1m      0.509359
# 547             min_cat13_spend_1m      0.509300
# 762   min_cat18_to_income_ratio_3m      0.509250
# 1757            min_cat43_spend_3m      0.509167
# 1706             sd_cat42_spend_1m      0.509163
# 12                  min_3m_netflow      0.509105
# 1160  med_cat28_to_income_ratio_3m      0.509105
# 1868            max_cat46_spend_1m      0.509037
# 665             med_cat16_spend_1m      0.509018
# 1627            min_cat40_spend_1m      0.508985
# 559   avg_cat13_to_income_ratio_3m      0.508899
# 1597            min_cat39_spend_3m      0.508868
# 879   avg_cat21_to_income_ratio_3m      0.508822
# 757             min_cat18_spend_3m      0.508788
# 1305            med_cat32_spend_1m      0.508774
# 841    sd_cat20_to_income_ratio_3m      0.508713
# 596              sd_cat14_spend_3m      0.508600
# 1638            max_cat40_spend_3m      0.508590
# 562   min_cat13_to_income_ratio_3m      0.508526
# 839   avg_cat20_to_income_ratio_3m      0.508119
# 1668            max_cat41_spend_1m      0.508049
# 1354            avg_cat33_spend_3m      0.507984
# 1664            avg_cat41_spend_1m      0.507943
# 1276             sd_cat31_spend_3m      0.507839
# 1518            max_cat37_spend_3m      0.507799
# 1274            avg_cat31_spend_3m      0.507775
# 1836             sd_cat45_spend_3m      0.507711
# 1358            max_cat33_spend_3m      0.507699
# 874             avg_cat21_spend_3m      0.507651
# 1634            avg_cat40_spend_3m      0.507589
# 667             min_cat16_spend_1m      0.507347
# 995             med_cat24_spend_3m      0.507342
# 1145            med_cat28_spend_1m      0.507293
# 1760  med_cat43_to_income_ratio_3m      0.507165
# 1195            med_cat29_spend_3m      0.507132
# 56                sd_cat0_spend_9m      0.507069
# 1359  avg_cat33_to_income_ratio_3m      0.506838
# 1906             sd_cat47_spend_1m      0.506783
# 876              sd_cat21_spend_3m      0.502993
# 696              sd_cat16_spend_9m      0.502975
# 1349  avg_cat33_to_income_ratio_1m      0.502959
# 1225            med_cat30_spend_1m      0.502941
# 1670  med_cat41_to_income_ratio_1m      0.502916
# 475             med_cat11_spend_3m      0.502890
# 1631   sd_cat40_to_income_ratio_1m      0.502756
# 1507            min_cat37_spend_1m      0.502718
# 1672  min_cat41_to_income_ratio_1m      0.502565
# 1399  avg_cat34_to_income_ratio_3m      0.502389
# 669   avg_cat16_to_income_ratio_1m      0.502366
# 985             med_cat24_spend_1m      0.502362
# 1547            min_cat38_spend_1m      0.502323
# 1307            min_cat32_spend_1m      0.502234
# 1345            med_cat33_spend_1m      0.502036
# 1267            min_cat31_spend_1m      0.502027
# 1157            min_cat28_spend_3m      0.502017
# 480   med_cat11_to_income_ratio_3m      0.502015
# 1705            med_cat42_spend_1m      0.501851
# 1550  med_cat38_to_income_ratio_1m      0.501835
# 829   avg_cat20_to_income_ratio_1m      0.501773
# 1279  avg_cat31_to_income_ratio_3m      0.501625
# 1082  min_cat26_to_income_ratio_3m      0.501610
# 1671   sd_cat41_to_income_ratio_1m      0.501590
# 1240  med_cat30_to_income_ratio_3m      0.501571
# 1152  min_cat28_to_income_ratio_1m      0.501384
# 864             avg_cat21_spend_1m      0.501322
# 1587            min_cat39_spend_1m      0.501297
# 1908            max_cat47_spend_1m      0.501267
# 1904            avg_cat47_spend_1m      0.501267
# 1624            avg_cat40_spend_1m      0.501152
# 1711   sd_cat42_to_income_ratio_1m      0.501053
# 1350  med_cat33_to_income_ratio_1m      0.500974
# 1748            max_cat43_spend_1m      0.500941
# 1744            avg_cat43_spend_1m      0.500930
# 1905            med_cat47_spend_1m      0.500851
# 1683  max_cat41_to_income_ratio_3m      0.500840
# 1348            max_cat33_spend_1m      0.500824
# 1679  avg_cat41_to_income_ratio_3m      0.500822
# 835             med_cat20_spend_3m      0.500758
# 1667            min_cat41_spend_1m      0.500757
# 1552  min_cat38_to_income_ratio_1m      0.500736
# 598             max_cat14_spend_3m      0.500700
# 1387            min_cat34_spend_1m      0.500692
# 1678            max_cat41_spend_3m      0.500614
# 1347            min_cat33_spend_1m      0.500606
# 1599  avg_cat39_to_income_ratio_3m      0.500561
# 878             max_cat21_spend_3m      0.500521
# 1147            min_cat28_spend_1m      0.500501
# 1546             sd_cat38_spend_1m      0.500447
# 1674            avg_cat41_spend_3m      0.500444
# 1745            med_cat43_spend_1m      0.500293
# 1275            med_cat31_spend_3m      0.500230
# 1907            min_cat47_spend_1m      0.500142
# 1322  min_cat32_to_income_ratio_3m      0.500109
# 1665            med_cat41_spend_1m      0.500019
# 1997            min_cat49_spend_3m      0.500000
# 1661   sd_cat40_to_income_ratio_9m      0.500000
# 1820  med_cat44_to_income_ratio_9m      0.500000
# 1821   sd_cat44_to_income_ratio_9m      0.500000
# 1822  min_cat44_to_income_ratio_9m      0.500000
# 2006             sd_cat49_spend_6m      0.500000
# 2005            med_cat49_spend_6m      0.500000
# 2004            avg_cat49_spend_6m      0.500000
# 1581   sd_cat38_to_income_ratio_9m      0.500000
# 2001   sd_cat49_to_income_ratio_3m      0.500000
# 2003  max_cat49_to_income_ratio_3m      0.500000
# 1998            max_cat49_spend_3m      0.500000
# 1999  avg_cat49_to_income_ratio_3m      0.500000
# 1611   sd_cat39_to_income_ratio_6m      0.500000
# 1621   sd_cat39_to_income_ratio_9m      0.500000
# 2000  med_cat49_to_income_ratio_3m      0.500000
# 1823  max_cat44_to_income_ratio_9m      0.500000
# 2002  min_cat49_to_income_ratio_3m      0.500000
# 1959  avg_cat48_to_income_ratio_3m      0.500000
# 2013  max_cat49_to_income_ratio_6m      0.500000
# 2007            min_cat49_spend_6m      0.500000
# 1776             sd_cat43_spend_9m      0.500000
# 1749  avg_cat43_to_income_ratio_1m      0.500000
# 1750  med_cat43_to_income_ratio_1m      0.500000
# 1751   sd_cat43_to_income_ratio_1m      0.500000
# 1752  min_cat43_to_income_ratio_1m      0.500000
# 1753  max_cat43_to_income_ratio_1m      0.500000
# 1762  min_cat43_to_income_ratio_3m      0.500000
# 1771   sd_cat43_to_income_ratio_6m      0.500000
# 1772  min_cat43_to_income_ratio_6m      0.500000
# 1779  avg_cat43_to_income_ratio_9m      0.500000
# 1747            min_cat43_spend_1m      0.500000
# 1780  med_cat43_to_income_ratio_9m      0.500000
# 1781   sd_cat43_to_income_ratio_9m      0.500000
# 1782  min_cat43_to_income_ratio_9m      0.500000
# ...
# 1070  med_cat26_to_income_ratio_1m      0.464936
# 504             avg_cat12_spend_1m      0.464500
# 1356             sd_cat33_spend_3m      0.464482
# 1476             sd_cat36_spend_3m      0.464451
# 1858            max_cat45_spend_9m      0.464185
# 1854            avg_cat45_spend_9m      0.464183
# 1855            med_cat45_spend_9m      0.464177
# 1857            min_cat45_spend_9m      0.464171
# 750   med_cat18_to_income_ratio_1m      0.463713
# 1218            max_cat29_spend_9m      0.462504
# 1214            avg_cat29_spend_9m      0.462501
# 1215            med_cat29_spend_9m      0.462489
# 1217            min_cat29_spend_9m      0.462482
# 1921   sd_cat47_to_income_ratio_3m      0.462031
# 1761   sd_cat43_to_income_ratio_3m      0.461883
# 516              sd_cat12_spend_3m      0.461747
# 217              min_cat4_spend_9m      0.460757
# 214              avg_cat4_spend_9m      0.460623
# 215              med_cat4_spend_9m      0.460617
# 218              max_cat4_spend_9m      0.460572
# 1109  avg_cat27_to_income_ratio_1m      0.460333
# 749   avg_cat18_to_income_ratio_1m      0.459505
# 1756             sd_cat43_spend_3m      0.459400
# 514             avg_cat12_spend_3m      0.459258
# 1361   sd_cat33_to_income_ratio_3m      0.459231
# 1418            max_cat34_spend_9m      0.459208
# 1414            avg_cat34_spend_9m      0.459046
# 1415            med_cat34_spend_9m      0.459011
# 1417            min_cat34_spend_9m      0.459004
# 1556             sd_cat38_spend_3m      0.458391
# 64               avg_cat1_spend_1m      0.458266
# 1862  min_cat45_to_income_ratio_9m      0.457866
# 1863  max_cat45_to_income_ratio_9m      0.457806
# 1085            med_cat26_spend_6m      0.392355
# 1087            min_cat26_spend_6m      0.391383
# 1164            avg_cat28_spend_6m      0.391349
# 1165            med_cat28_spend_6m      0.390279
# 1167            min_cat28_spend_6m      0.389399
# 1608            max_cat39_spend_6m      0.387632
# 87               min_cat1_spend_6m      0.385780
# 1604            avg_cat39_spend_6m      0.384792
# 1605            med_cat39_spend_6m      0.384444
# 1846             sd_cat45_spend_6m      0.384143
# 1326             sd_cat32_spend_6m      0.378940
# 1607            min_cat39_spend_6m      0.376419
# 1408            max_cat34_spend_6m      0.373702
# 1526             sd_cat37_spend_6m      0.373308
# 1206             sd_cat29_spend_6m      0.372400
# 1405            med_cat34_spend_6m      0.372381
# 1407            min_cat34_spend_6m      0.372368
# 1404            avg_cat34_spend_6m      0.371621
# 1845            med_cat45_spend_6m      0.370320
# 1848            max_cat45_spend_6m      0.369824
# 1844            avg_cat45_spend_6m      0.369187
# 1847            min_cat45_spend_6m      0.368336
# 1331   sd_cat32_to_income_ratio_6m      0.366194
# 1328            max_cat32_spend_6m      0.365597
# 1325            med_cat32_spend_6m      0.364807
# 1324            avg_cat32_spend_6m      0.364089
# 1327            min_cat32_spend_6m      0.363536
# 1691   sd_cat41_to_income_ratio_6m      0.360702
# 1208            max_cat29_spend_6m      0.359698
# 1726             sd_cat42_spend_6m      0.359427
# 1204            avg_cat29_spend_6m      0.359328
# 1207            min_cat29_spend_6m      0.358150
# 1205            med_cat29_spend_6m      0.358141
# 1566             sd_cat38_spend_6m      0.357601
# 1171   sd_cat28_to_income_ratio_6m      0.356873
# 491    sd_cat11_to_income_ratio_6m      0.356317
# 1571   sd_cat38_to_income_ratio_6m      0.354793
# 1525            med_cat37_spend_6m      0.354315
# 1211   sd_cat29_to_income_ratio_6m      0.353800
# 1411   sd_cat34_to_income_ratio_6m      0.353736
# 1524            avg_cat37_spend_6m      0.353632
# 1527            min_cat37_spend_6m      0.353148
# 1371   sd_cat33_to_income_ratio_6m      0.352373
# 1332  min_cat32_to_income_ratio_6m      0.351096
# 1766             sd_cat43_spend_6m      0.350634
# 1330  med_cat32_to_income_ratio_6m      0.350596
# 1612  min_cat39_to_income_ratio_6m      0.350289
# 1329  avg_cat32_to_income_ratio_6m      0.350281
# 1725            med_cat42_spend_6m      0.349833
# 1333  max_cat32_to_income_ratio_6m      0.349801
# 1724            avg_cat42_spend_6m      0.349790
# 1926             sd_cat47_spend_6m      0.349533
# 485             med_cat11_spend_6m      0.349023
# 484             avg_cat11_spend_6m      0.348946
# 1728            max_cat42_spend_6m      0.348904
# 1688            max_cat41_spend_6m      0.347865
# 1727            min_cat42_spend_6m      0.347544
# 1685            med_cat41_spend_6m      0.347259
# 1684            avg_cat41_spend_6m      0.346914
# 1609  avg_cat39_to_income_ratio_6m      0.346883
# 1610  med_cat39_to_income_ratio_6m      0.346661
# 487             min_cat11_spend_6m      0.346502
# 1491   sd_cat36_to_income_ratio_6m      0.346424
# 1291   sd_cat31_to_income_ratio_6m      0.346279
# 1687            min_cat41_spend_6m      0.345976
# 1692  min_cat41_to_income_ratio_6m      0.340954
# 1693  max_cat41_to_income_ratio_6m      0.340512
# 1690  med_cat41_to_income_ratio_6m      0.340284
# 1689  avg_cat41_to_income_ratio_6m      0.339998
# 1773  max_cat43_to_income_ratio_6m      0.337570
# 1769  avg_cat43_to_income_ratio_6m      0.337229
# 1212  min_cat29_to_income_ratio_6m      0.336972
# 1770  med_cat43_to_income_ratio_6m      0.336511
# 492   min_cat11_to_income_ratio_6m      0.336267
# 1530  med_cat37_to_income_ratio_6m      0.336137
# 1730  med_cat42_to_income_ratio_6m      0.335647
# 1732  min_cat42_to_income_ratio_6m      0.335601
# 490   med_cat11_to_income_ratio_6m      0.335540
# 1852  min_cat45_to_income_ratio_6m      0.334774
# 489   avg_cat11_to_income_ratio_6m      0.334583
# 1570  med_cat38_to_income_ratio_6m      0.334278
# 1572  min_cat38_to_income_ratio_6m      0.334245
# 493   max_cat11_to_income_ratio_6m      0.333847
# 1532  min_cat37_to_income_ratio_6m      0.333649
# 1850  med_cat45_to_income_ratio_6m      0.333629
# 1569  avg_cat38_to_income_ratio_6m      0.333553
# 1853  max_cat45_to_income_ratio_6m      0.333375
# 1849  avg_cat45_to_income_ratio_6m      0.333277
# 1573  max_cat38_to_income_ratio_6m      0.333146
# 1213  max_cat29_to_income_ratio_6m      0.332914
# 1568            max_cat38_spend_6m      0.332809
# 1209  avg_cat29_to_income_ratio_6m      0.332799
# 1210  med_cat29_to_income_ratio_6m      0.332347
# 1412  min_cat34_to_income_ratio_6m      0.332246
# 1369  avg_cat33_to_income_ratio_6m      0.331797
# 1370  med_cat33_to_income_ratio_6m      0.331705
# 1373  max_cat33_to_income_ratio_6m      0.331385
# 1410  med_cat34_to_income_ratio_6m      0.331229
# 1409  avg_cat34_to_income_ratio_6m      0.331139
# 1768            max_cat43_spend_6m      0.331136
# 1413  max_cat34_to_income_ratio_6m      0.331105
# 1764            avg_cat43_spend_6m      0.330728
# 1765            med_cat43_spend_6m      0.330010
# 1767            min_cat43_spend_6m      0.329155
# 572   min_cat13_to_income_ratio_6m      0.328552
# 1924            avg_cat47_spend_6m      0.326982
# 1928            max_cat47_spend_6m      0.326982
# 1925            med_cat47_spend_6m      0.326738
# 1927            min_cat47_spend_6m      0.326211
# 1493  max_cat36_to_income_ratio_6m      0.324595
# 1492  min_cat36_to_income_ratio_6m      0.324347
# 1490  med_cat36_to_income_ratio_6m      0.324257
# 932   min_cat22_to_income_ratio_6m      0.324245
# 1489  avg_cat36_to_income_ratio_6m      0.324005

# %%
# auc_df[auc_df['max_auc'] == 'auc_roc_mean']

# %%
# auc_df[auc_df['max_auc'] == 'auc_roc_med']

# %%
X = feature_cols
y = y

model = LogisticRegression(class_weight='balanced')
model.fit(X, y)

preds = model.predict_proba(X)[:, 1]

score = roc_auc_score(y, preds)

# auc_df = pd.concat([auc_df, pd.DataFrame([{"feature": col, "auc_roc_mean": score}])],ignore_index=True)
# print(col)
print(len(feature_cols))
print(score)
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 11516
# 0.7797731539667023
